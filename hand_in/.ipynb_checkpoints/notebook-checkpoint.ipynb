# %% [markdown]
# ### Introduction
#
# Forecasting energy prices in Germany is a challenging task due to the complex interplay of multiple factors, including renewable energy generation, fossil fuel prices, weather conditions, and market regulations. The growing share of renewables in the country’s power grid has introduced additional volatility, making accurate price prediction even more difficult.
#
# Our project, the “BTW 2025 Data Science Challenge,” aims to develop predictive models to predict hourly day-ahead energy prices for Germany on February 18, 2025, using historical data. This report begins with an overview of the domain knowledge surrounding Germany’s energy market, followed by a discussion of the data sources used in modeling. Subsequent sections will detail the methodology, present modeling results, and offer conclusions.
#
# #TO DO: Rewrite second part: It is a part of the challenge not our project - we are participating in the data science challenge etc.

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
# Out:
#   Cell In[1], line 3
#     import tqdm from tqdm
#     ^
# SyntaxError: Did you mean to use 'from ... import ...' instead?

# %%
from src.widgets import get_config_widgets, select_features
from src.dataset import get_datasets, correlation_analysis
from src.feature import create_features, split, create_features_and_split_datasets, get_sets
from src.plot import plot_price_split, plot_energy_mix
from src.scraping import (
    update_e_mix_data,
    update_e_price_data,
    fetch_historical_weather,
)
from src.final_prediction import fill_up_e_prices, fill_up_energy_mix

# %%
# update_e_price_data()
# update_e_mix_data()
# fetch_historical_weather()

# %% [markdown]
# ## 1. Background & Domain Knowledge

# %% [markdown]
# ### 1.1 Energy Market and Price Dynamics
# In Germany, electricity pricing comprises consumer electricity fees and wholesale market prices, with the day-ahead market being a key indicator of wholesale price fluctuations. Prices in this market are determined by the “merit order principle,” in which power plants with the lowest marginal costs are utilized first to meet demand. Because renewable energy sources generally have low marginal costs, they are dispatched preferentially. However, oversupply in addition of limitations in the grid can lead to negative prices (Wissenschaftliche Dienste, 2022).
#
# **These dynamics underscore the importance of closely examining both supply-side and demand-side variables when forecasting energy prices.** # TO DO: decide if we include demand in the background knowledge
#
# #TO DO: Price determined by last power plant

# %% [markdown]
# ### 1.2 Energy Mix
# Germany’s energy mix has evolved significantly, with the share of renewables reaching about 50% of total generation in 2023 (BMWK-Energiewende, 2024). Among these, wind and solar power dominate:
# - Wind Power: Peaks during winter to spring due to higher wind speeds, typically exerting downward pressure on prices (Clean Energy Wire).
# - Solar Power: Generates more electricity in summer, reducing prices during daylight hours (Sebastian Kolb, 2020; IMF, 2022).
#
# Despite the rise in renewables, fossil fuels—including hard coal, lignite, and natural gas—still play a critical role. They contribute to price volatility, influenced by fluctuating fuel costs and carbon pricing (Nature, 2024). Understanding both the renewable and fossil-fuel components of the energy mix is therefore crucial for accurate price forecasting.
#
# #TO DO: Add hyptothesis on how the energy mix influences the prices
#
# #TO DO: check sources, decide if we keep the sources because proof is in our model results

# %%
plot_energy_mix()

# %% [markdown]
# This plot represents the proportional composition of different energy sources (production in Germany) over the last 72 hours. Each color represents a different energy source contributing to the total energy mix at a particular time.
# #TO DO: Add underlining context to the plot

# %% [markdown]
# ### 1.3 Weather Impacts
# Weather conditions significantly affect energy supply and demand, thereby influencing prices. Key factors include:
# - Wind Speeds: Higher winds, especially in northern Germany, boost renewable generation and typically lower prices (Tanaka et al., 2022; Mosquera-Lopez et al., 2024).
# - Solar Irradiance: Stronger sunlight in southern regions increases solar power output, putting downward pressure on prices.
# - Temperature:
#   - Low Temperatures → Increased heating demand → Higher prices
#   - High Temperatures → Increased cooling demand → Higher prices
# - Precipitation: Affects prices with a delayed impact, possibly by influencing hydropower generation or overall energy demand (Mosquera-Lopez et al., 2024; Springer, 2022; IMF, 2022).

# %% [markdown]
# ## 2. Data Cleaning

# %% [markdown]
# Understanding and preparing the data is a crucial step in any predictive modeling task. In energy price forecasting, data reliability, completeness, and structure play a fundamental role in ensuring the models can capture key trends and dependencies. Given the complexity of the energy market, multiple data sources were used, each contributing essential information. However, some critical datasets were not readily accessible—gas and oil price data were behind a paywall, preventing their inclusion, and electricity demand data was available but consistently missing the last three days, making it unreliable for modeling. Addressing these challenges required careful data cleaning, merging, and feature engineering to build a robust foundation for forecasting models.

# %% [markdown]
# ## 2.1 Data Sources & Reliabality
#
# Ensuring the reliability of data sources is fundamental in energy price modeling. The datasets used in this analysis are sourced from reputable organizations: Energy prices are sourced from SMARD.de, a platform operated by the German Federal Network Agency, which is recommended for energy price data. Weather data is obtained from Open-Meteo, a provider of historical and forecast weather information that collaborates with national weather services. Data on the energy mix is provided by Agora Energiewende, which offers interactive tools and datasets widely used for analyzing energy mix information. (SMARD, 2025) (Agora Energiewende, 2025)

# %% [markdown]
# ## 2.2 Data Cleaning and Preparation
# To ensure the datasets were ready for analysis, a thorough data cleaning process was carried out. The first step involved handling missing data. One notable challenge was the absence of nuclear energy data after April 15, 2023, due to Germany’s nuclear phase-out. Additionally, any missing values in other datasets were addressed by re-fetching the data from their respective sources to maintain completeness. Ensuring a fully populated dataset was crucial for maintaining consistency across all variables and enabling reliable model training.
# Another key aspect was outlier detection. Given the inherent volatility of energy prices, extreme values were carefully examined rather than being removed outright. Instead of discarding outliers indiscriminately, we assessed their impact on the model’s performance. In some cases, extreme values contained meaningful signals about rare market conditions and were retained to ensure the model could adapt to such situations. Each outlier was evaluated in context, preserving those that could provide valuable insights while mitigating the effect of spurious anomalies.
# After cleaning the data, we merged different datasets to establish a comprehensive dataset for modeling. Weather data, energy price data, and energy mix data were aligned by date, ensuring that all records were synchronized correctly. This step was crucial for creating a structured dataset that allowed for meaningful feature extraction and analysis in the subsequent modeling phase.

# %% [markdown]
# ## 2.3 Correlation Analysis
# We explored the relationship between different factors (weather variables, energy mix) and energy prices. Initial findings revealed an inverse correlation between renewable energy generation (solar, wind onshore, wind offshore, hydro) and energy prices, with an observed moderate negative correlation coefficient of -0.312. (pic a)

# %%
correlation_analysis()
# Out:
# Test Score:  -0.30497358159480326
# One Tailed P-Value:  1.1102230246251565e-16

# %% [markdown]
# The following scatter plot shows a moderate negative correlation (r = -0.312) between renewable energy generation (solar, wind onshore, wind offshore, hydro) and electricity prices. While renewables lower prices due to their low marginal costs, other factors like demand, fossil fuel prices, and regulations also influence price fluctuations
#
#
# #TO DO: Rewrite explanation for better strucutre and clarity

# %% [markdown]
# #TODO: make trendline for correlation of energy price and temp or wind speed

# %% [markdown]
# ## Data loading

# %% [markdown]
# #DO TO: Explanation for removing outliers

# %%
merged_df, e_price_df = get_datasets()

# %% [markdown]
# ## Configuration

# %%
price_interval, eval_size, normalize =  get_config_widgets()
# Out:
# IntRangeSlider(value=(-20, 400), continuous_update=False, description='Energy Price Interval', max=900, min=-5…
# FloatSlider(value=0.05, description='Evaluation Set Size', max=0.2, step=0.01)
# Checkbox(value=False, description='Normalize')

# %% [markdown]
# ## 3. Features
# #TO DO: Feature selection - autoML
#
# Selecting relevant features is crucial for building an effective predictive model. Given the diverse range of available data—including time-based attributes, moving averages, energy generation sources, and weather variables—our selection process focused on maximizing predictive power while avoiding redundancy.
# Since energy prices exhibit strong temporal dependencies, time-based features were incorporated to capture seasonal and weekly patterns. The importance of these features has been previously discussed in the context of price dynamics (see Section 1.1.1). Additionally, moving averages played a key role in smoothing short-term fluctuations and enhancing model stability, as outlined in Section 3.1.
# Beyond time-related attributes, energy mix variables were selected based on their direct impact on electricity prices. Renewable energy sources, particularly solar and hydro, were included due to their well-documented influence on price formation. Weather variables, such as temperature, precipitation, and direct radiation, were chosen for their role in both energy demand and renewable generation variability. These relationships have been analyzed in Section 1.1.3, reinforcing their relevance in predictive modeling.
# By carefully curating our feature set, we ensured that the model balances complexity and interpretability while capturing the fundamental drivers of energy price fluctuations. This selection process aimed to improve forecasting accuracy without introducing unnecessary computational overhead.

# %% [markdown]
# ## 3.1 Moving Averages and Their Role in Forecasting
# Moving averages are essential for smoothing out short-term fluctuations in time-series data and revealing underlying trends. By averaging values over a defined window, moving averages reduce noise and enhance the visibility of long-term patterns.
# For linear regression-based models, moving averages provide several benefits:
# - *Noise Reduction*: Energy price data can be volatile due to external shocks, market fluctuations, and unexpected demand surges. Moving averages help smooth these fluctuations, enabling the model to focus on broader trends rather than reacting to random variations.
# - *Feature Engineering*: Moving averages can serve as additional explanatory variables in regression models, capturing smoothed past behavior that informs future predictions.
# Seasonality Handling: By choosing appropriate window sizes (e.g., 24-hour, 7-day, or 30-day moving averages), it is possible to better capture daily, weekly, or monthly cycles in energy prices.
# - *Enhanced Interpretability*: Linear models often struggle with high-frequency variations. Incorporating moving averages helps them generalize better by reducing the emphasis on short-term noise.
# Given the time-series nature of energy prices, we applied moving averages with various window sizes (e.g., hourly and daily) to analyze how different trends affect price fluctuations. This was particularly useful in identifying seasonal effects and ensuring that models could make robust predictions without overfitting to short-term anomalies.

# %%
get_features, default_features = select_features()
# Out:
# GridBox(children=(Checkbox(value=True, description='hour'), Checkbox(value=True, description='dayofyear'), Che…
# Output()
# Button(description='Confirm Selection', style=ButtonStyle())

# %%
# RERUN WHEN TICKING the NORMALIZED BOX
min_price, max_price = price_interval.value

(
    train,
    eval,
    test,
    benchmark,
    SPLIT_DATE_EVAL,
    SPLIT_DATE_TEST,
    SPLIT_DATE_BENCHMARK,
    train_interval,
    eval_interval,
    test_interval,
    benchmark_interval,
    SPLIT_DATE_EVAL_INTERVAL,
    SPLIT_DATE_TEST_INTERVAL,
    SPLIT_DATE_BENCHMARK,
    scalar,
    FEATURES
) = create_features_and_split_datasets(
    merged_df.copy(),
    default_features,
    get_features(),
    min_price,
    max_price,
    e_price_df.copy(),
    normalize.value,
    eval_size.value,
)


(   X_train, y_train, X_val, y_val, X_test, y_test,
    X_train_interval,
    y_train_interval,
    X_val_interval,
    y_val_interval,
    X_test_interval,
    y_test_interval,
) = get_sets(train, eval, test, train_interval, eval_interval, test_interval, FEATURES)

# %%
plot_price_split(train, eval, test, benchmark, SPLIT_DATE_EVAL, SPLIT_DATE_TEST, SPLIT_DATE_BENCHMARK, "outliers includuded")
plot_price_split(train_interval, eval_interval, test_interval, benchmark_interval, SPLIT_DATE_EVAL_INTERVAL, SPLIT_DATE_TEST_INTERVAL, SPLIT_DATE_BENCHMARK, "ex outliers")

# %% [markdown]
# ## 3.2 Evaluation Criteria
#
# To assess model performance, we considered the following:
# 1. Error Objectiv Functions
# - RMSE (Root Mean Squared Error): Measures overall prediction error, with a stronger penalty for large deviations.
# - MAE (Mean Absolute Error): Reflects the average magnitude of errors without emphasizing outliers as strongly as RMSE.
# - MSE (Mean Squared Error): Calculates the average of the squared differences between actual and predicted values, providing a general measure of error while penalizing larger errors more than MAE.
# - MAPE (Mean Absolute Percentage Error): Expresses the average absolute error as a percentage of actual values, making it useful for comparing errors across different scales or datasets.
# 2. Handling of Seasonality and Outliers
# - The ability to capture daily, weekly, and yearly seasonality effectively.
# - Robustness to price spikes and outliers due to external factors like demand surges or market shocks.
# 3. Ease of Interpretation
# - Linear models like Regression provide direct insight into feature importance.
# - Prophet allows for intuitive trend and seasonality decomposition.
# - XGBoost requires careful feature engineering to extract meaningful insights.
# 4. Faster Iteration and Scalability
# - Training time and computational efficiency.
# - Ability to adapt and fine-tune hyperparameters efficiently.

# %% [markdown]
# ## 4 Model Selection and Training
#
#
# #TODO: Add Explanation about using benchmark model
#
# Selecting an appropriate modeling approach is a critical step in building a reliable forecasting system. Given the complexity of energy price dynamics, the choice of models must balance accuracy, interpretability, and computational efficiency. A well-defined modeling strategy typically begins with a simple yet effective baseline model before progressing to more advanced techniques. This ensures that improvements gained from sophisticated models are measured against a meaningful reference point. In this section, we outline the reasoning behind our model selection process, beginning with a baseline model and advancing to more specialized forecasting methods.
# ## 4.1 Choosing a Baseline Model
# For our initial baseline model, we selected Linear Regression due to its simplicity, interpretability, and computational efficiency. Linear Regression provides a straightforward approach to capturing linear relationships in the data, making it an excellent reference point for evaluating more complex models. However, it struggles with capturing non-linear dependencies and seasonality, which are crucial in energy price forecasting.
# We opted against using neural networks due to several reasons:
# - **Computational Cost**: Training deep learning models requires significant computational resources, which were not justified given the available dataset size and forecasting horizon.
# - **Interpretability**: Neural networks act as black-box models, making it difficult to extract insights about seasonal trends, price spikes, or external influencing factors.
# - **Data Requirements**: Deep learning models typically require large amounts of high-quality data to generalize well. Given our dataset’s structure, traditional time-series models were more suitable.
# ## 4.2 XGBoost
# XGBoost (Extreme Gradient Boosting) is a machine learning algorithm based on decision trees, well-suited for structured datasets like ours. It excels at capturing non-linear relationships, allowing it to model complex interactions between features and energy prices, which Linear Regression cannot do. XGBoost also provides built-in feature importance metrics, helping identify key factors like weather, energy mix, and demand fluctuations. It handles missing data and outliers better than traditional models, making it a robust choice for real-world forecasting. Computationally efficient compared to deep learning models, XGBoost performs well for our dataset, although it requires feature engineering and hyperparameter tuning. Its ability to capture short-term fluctuations and complex feature interactions can enhance forecasting accuracy.
#
# ### TODO: add explanation fpr gradiant boosting
# ## 4.3 Prophet
# Prophet, developed by Facebook, is designed for time-series forecasting, particularly in capturing seasonality, trends, and holiday effects. It automatically detects daily, weekly, and yearly seasonality, which is helpful for energy price forecasting, where such patterns dominate. Prophet is robust to missing data and outliers, improving forecast reliability. Unlike traditional models, Prophet allows trend changes over time, making it ideal for dynamic markets. It also provides clear decompositions of trend, seasonality, and holiday effects, offering interpretability that aids understanding of energy price drivers. Prophet’s combination of seasonality detection, trend flexibility, and ease of use makes it a powerful tool for forecasting energy prices.

# %% [markdown]
# ### Linear Regression

# %%
# lr_prediction = linear_regression(X_train, y_train, X_test, y_test, scalar)

# %% [markdown]
# ### XGBoost

# %%
# xgb_y_prediction_mse, xgb_mse = predict_mse(
#     X_train_interval, y_train_interval, X_val_interval, y_val_interval, X_test_interval, scalar
# )
# xgb_y_prediction_mae, xgb_mae = predict_mae(
#     X_train_interval, y_train_interval, X_val_interval, y_val_interval, X_test_interval, scalar
# )

# feature_importance((xgb_mse, xgb_mae))

# %% [markdown]
# ### Prophet

# %%
# prophet_prediction = prophet_predict(FEATURES, train, test, scalar)

# %%
# if scalar:
#     y_test = unnormalize(y_test, scalar)

# %% [markdown]
# ## Results

# %% [markdown]
# ### Errors

# %%
# calculate_error_metrics(
#     y_test, [lr_prediction, prophet_prediction, xgb_y_prediction_mse, xgb_y_prediction_mae]
# )

# %% [markdown]
# ### Plots

# %%
# predictions = [
#     (prophet_prediction, "Prophet", "MSE"),
#     (xgb_y_prediction_mse, "XGBoost", "MSE"),
#     (xgb_y_prediction_mae, "XGBoost", "MAE"),
#     (lr_prediction, "Linear Regression", "MSE"),
# ]

# plot_predicted(y_test, predictions)

# %% [markdown]
# ## Benchmarking

# %%
# Constants and Configurations
# =============================================================================

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from xgboost import XGBRegressor
from src.benchmark import extend_by_predictions_and_samples, print_date_ranges
from src.plot import plot_benchmark_predictions
from src.prediction import init_prophet_model

WINDOW_SIZE = 24  # Forecasting window of 24 hours

# Columns to use from the datasets
COLUMNS = [
    "Price",
    "Hydro",
    "Pumped storage generation",
    "Solar",
    "Wind offshore",
    "Wind onshore",
    "temperature_2m",
    "precipitation",
    "wind_speed_100m",
    "direct_radiation",
]

# Final features used for model training and forecasting
FINAL_FEATURES = [
    "hour",
    "dayofyear",
    "dayofweek",
    "Hydro",
    "Pumped storage generation",
    "Solar",
    "Wind offshore",
    "Wind onshore",
    "temperature_2m",
    "precipitation",
    "wind_speed_100m",
    "direct_radiation",
]

FINAL_FEATURES_XGB = [
    "Pumped storage generation",
    "Solar",
    "Wind offshore",
    "temperature_2m",
    "wind_speed_100m",
    "hour",
    "dayofweek",
    "dayofyear",
    "ma_1_days",
    "ma_1_days_pumped_storage_generation",
    "ma_2_days",
    "ma_2_days_pumped_storage_generation",
    "ma_3_days",
    "ma_4_days_pumped_storage_generation",
    "ma_5_days_pumped_storage_generation",
    "ma_6_days",
    "ma_7_days",
    "ma_8_days_pumped_storage_generation",
    "ma_9_days_pumped_storage_generation",
    "ma_10_days",
    "ma_11_days",
    "ma_12_days_pumped_storage_generation",
    "ma_13_days",
    "ma_14_days_pumped_storage_generation",
]

XGB_hyp_params = {
    "base_score": 0.5789230150549212,
    "learning_rate": 0.006032821602006745,
    "max_depth": 90,
    "n_estimators": 888,
    "gamma": 4.026209209533667,
    "min_child_weight": 4,
    "subsample": 0.7320835295857154,
    "colsample_bylevel": 0.8758263640368676,
    "max_delta_step": 0,
    "early_stopping_rounds": 80,
}


XGB_hyp_params_old = {
    "base_score": 0.380924762889507,
    "early_stopping_rounds": 215,
    "max_depth": 80,
    "learning_rate": 0.06,
    "n_estimators": 150,
    "gamma": 0.9,
    "min_child_weight": 6,
    "subsample": 0.5719023844219375,
    "colsample_bytree": 0.8815691043681952,
}


# =========================================================================
# 1. Data Preparation
# =========================================================================

# Get and split datasets
merged_df, _ = get_datasets()
train, eval, test, benchmark, _, _, _ = split(merged_df)

# Combine all available training data
training_set = pd.concat([train, eval, test])[COLUMNS]
# Benchmark dataset for rolling forecast
benchmarking_set = benchmark[COLUMNS]

# Lists to hold evaluation metrics for each window
rmses = []  # Will store tuples of (prophet_rmse, lr_rmse, xgb_rmse)
# mean_errs = []  # Will store mean errors for Prophet

# =========================================================================
# 2. Rolling Forecast Loop
# =========================================================================

# We start from 28 * 24 hours in, to skip an initial period if needed
for window_start in tqdm(range(24, len(benchmarking_set) - WINDOW_SIZE, WINDOW_SIZE)):
    # Current forecast window for the next 24 hours
    y_actual = benchmarking_set.iloc[window_start : window_start + WINDOW_SIZE]["Price"]
    print("\nDate to predict: ", y_actual.index[0])

    # Extend the dataset with available data prior to the forecast window
    dataset_extended = pd.concat((training_set, benchmarking_set.iloc[:window_start]))
    next_day = dataset_extended.index[-1] + pd.DateOffset(hours=1)

    # If there's a gap in data, skip the forecast for this window
    if next_day != y_actual.index[0]:
        print(
            f"\nSkipping prediction for {next_day} due to missing entries.\n"
            "--------------------------------------------------------------\n"
        )
        continue

    # Extend the dataset by predicted values and samples if necessary
    dataset_extended_ps = extend_by_predictions_and_samples(
        dataset_extended, dataset_extended.index[-1]
    )

    # Create features required for model training and for predictions
    dataset_extended_features = create_features(dataset_extended_ps)

    # Split for training (all but last 24 hours) and prediction (the next 24 hours)
    VALIDATION_SET_SIZE = 24 * 14
    X_train_df = dataset_extended_features.iloc[:-WINDOW_SIZE - VALIDATION_SET_SIZE]
    X_eval_df = dataset_extended_features.iloc[-WINDOW_SIZE - VALIDATION_SET_SIZE : -WINDOW_SIZE]
    X_predict_df = dataset_extended_features.reindex(y_actual.index)[FINAL_FEATURES_XGB]

    # Prepare Prophet-compatible dataframe
    # Prophet requires 'ds' (date/time) and 'y' (target) columns.
    # X_train_prophet = (
    #     X_train_df[["Price"] + FINAL_FEATURES]
    #     .rename(columns={"Price": "y"})
    #     .reset_index()
    #     .rename(columns={"index": "ds"})
    #     .dropna()
    # )
    # prophet_X_predict = X_predict_df.reset_index().rename(columns={"index": "ds"})

    # =====================================================================
    # 2.1. Prophet Model
    # =====================================================================
    # If using a custom initialization, the function might set up seasonality, holidays, etc.
    # prophet_model = init_prophet_model(FINAL_FEATURES)
    # prophet_model.fit(X_train_prophet)

    # Generate a forecast. Adding constant to Prophet's forecast can offset a systematic bias.
    # prophet_forecast = prophet_model.predict(prophet_X_predict)["yhat"] + 13

    # =====================================================================
    # 2.2. Linear Regression
    # =====================================================================
    lr = LinearRegression()
    lr.fit(X_train_df[FINAL_FEATURES_XGB], X_train_df["Price"])
    lr_forecast = lr.predict(X_predict_df)

    # =====================================================================
    # 2.3. XGBoost
    # =====================================================================
    xgb_model = XGBRegressor(**XGB_hyp_params, n_jobs=-1)
    xgb_model.fit(X_train_df[FINAL_FEATURES_XGB], X_train_df["Price"], eval_set=[(X_eval_df[FINAL_FEATURES_XGB], X_eval_df["Price"])])
    xgb_forecast = xgb_model.predict(X_predict_df)

    # Display date ranges used (for debugging/traceability)
    # print_date_ranges(
    #     X_train_prophet,
    #     X_train_df[FINAL_FEATURES],
    #     X_train_df["Price"],
    #     y_actual,
    #     prophet_X_predict,
    #     X_predict_df,
    # )

    # =====================================================================
    # 2.4. Plot Predictions
    # =====================================================================
    plot_benchmark_predictions(
        y_actual,
        X_predict_df,
        # prophet_X_predict,
        # prophet_forecast,
        prophet_X_predict=None,
        prophet_prediction=None,
        lr_prediction=lr_forecast,
        xgb_prediction=xgb_forecast,
    )

    # =====================================================================
    # 2.5. Compute Metrics
    # =====================================================================
    # prophet_rmse = np.sqrt(mean_squared_error(y_actual, prophet_forecast))
    lr_rmse = np.sqrt(mean_squared_error(y_actual, lr_forecast))
    xgb_rmse = np.sqrt(mean_squared_error(y_actual, xgb_forecast))

    # mean_error_prophet = (prophet_forecast.to_numpy() - y_actual.to_numpy()).mean()

    # Print metrics for this window
    # print(f"Prophet RMSE: {prophet_rmse}")
    print(f"Linear Regression RMSE: {lr_rmse}")
    print(f"XGBoost RMSE: {xgb_rmse}")
    # print(f"Mean Error (Prophet): {mean_error_prophet}")
    print("--------------------------------------------------------")

    # Accumulate metrics for later averaging
    rmses.append((lr_rmse, xgb_rmse))
    # rmses.append((prophet_rmse, lr_rmse, xgb_rmse))
    # mean_errs.append(mean_error_prophet)

# =========================================================================
# 3. Compute Average Metrics and Print Results
# =========================================================================

if rmses:
    avg_rmse = tuple(sum(x) / len(rmses) for x in zip(*rmses))
    # mean_mean_err = np.mean(mean_errs)
    print(
        f"Linear Regression: {avg_rmse[0]}, XGBoost: {avg_rmse[1]}"
    )
    # print(
    #     f"\nAverage RMSEs - Prophet: {avg_rmse[0]}, "
    #     f"Linear Regression: {avg_rmse[1]}, XGBoost: {avg_rmse[2]}"
    # )
    # print(f"Average Mean Error (Prophet): {mean_mean_err}")
else:
    print("No forecasts were computed. Check data availability and index alignment.")
# Out:
# Date to predict:  2025-01-07 00:00:00
# [0]	validation_0-rmse:94.16487
# [1]	validation_0-rmse:93.62223
# [2]	validation_0-rmse:93.08535
# [3]	validation_0-rmse:92.54260
# [4]	validation_0-rmse:91.99814
# [5]	validation_0-rmse:91.46292
# [6]	validation_0-rmse:90.93652
# [7]	validation_0-rmse:90.41629
# [8]	validation_0-rmse:89.89188
# [9]	validation_0-rmse:89.37265
# [10]	validation_0-rmse:88.87077
# [11]	validation_0-rmse:88.35529
# [12]	validation_0-rmse:87.84716
# [13]	validation_0-rmse:87.33760
# [14]	validation_0-rmse:86.85727
# [15]	validation_0-rmse:86.35809
# [16]	validation_0-rmse:85.85556
# [17]	validation_0-rmse:85.35722
# [18]	validation_0-rmse:84.86510
# [19]	validation_0-rmse:84.37110
# [20]	validation_0-rmse:83.88925
# [21]	validation_0-rmse:83.40236
# [22]	validation_0-rmse:82.92801
# [23]	validation_0-rmse:82.47215
# [24]	validation_0-rmse:81.98865
# [25]	validation_0-rmse:81.53378
# [26]	validation_0-rmse:81.06646
# [27]	validation_0-rmse:80.62009
# [28]	validation_0-rmse:80.16659
# [29]	validation_0-rmse:79.71416
# [30]	validation_0-rmse:79.27338
# [31]	validation_0-rmse:78.83873
# [32]	validation_0-rmse:78.39570
# [33]	validation_0-rmse:77.95116
# [34]	validation_0-rmse:77.51062
# [35]	validation_0-rmse:77.05182
# [36]	validation_0-rmse:76.59721
# [37]	validation_0-rmse:76.14357
# [38]	validation_0-rmse:75.71620
# [39]	validation_0-rmse:75.29149
# [40]	validation_0-rmse:74.87052
# [41]	validation_0-rmse:74.45171
# [42]	validation_0-rmse:74.03202
# [43]	validation_0-rmse:73.59949
# [44]	validation_0-rmse:73.18434
# [45]	validation_0-rmse:72.76817
# [46]	validation_0-rmse:72.37650
# [47]	validation_0-rmse:71.97308
# [48]	validation_0-rmse:71.57221
# [49]	validation_0-rmse:71.19137
# [50]	validation_0-rmse:70.80416
# [51]	validation_0-rmse:70.41963
# [52]	validation_0-rmse:70.01857
# [53]	validation_0-rmse:69.63171
# [54]	validation_0-rmse:69.25944
# [55]	validation_0-rmse:68.88386
# [56]	validation_0-rmse:68.49844
# [57]	validation_0-rmse:68.11914
# [58]	validation_0-rmse:67.73435
# [59]	validation_0-rmse:67.36645
# [60]	validation_0-rmse:66.99485
# [61]	validation_0-rmse:66.63421
# [62]	validation_0-rmse:66.26246
# [63]	validation_0-rmse:65.89327
# [64]	validation_0-rmse:65.53871
# [65]	validation_0-rmse:65.18314
# [66]	validation_0-rmse:64.81939
# [67]	validation_0-rmse:64.46064
# [68]	validation_0-rmse:64.09299
# [69]	validation_0-rmse:63.72850
# [70]	validation_0-rmse:63.38258
# [71]	validation_0-rmse:63.03040
# [72]	validation_0-rmse:62.69338
# [73]	validation_0-rmse:62.34247
# [74]	validation_0-rmse:62.00882
# [75]	validation_0-rmse:61.67553
# [76]	validation_0-rmse:61.34656
# [77]	validation_0-rmse:61.00886
# [78]	validation_0-rmse:60.67539
# [79]	validation_0-rmse:60.34071
# [80]	validation_0-rmse:60.00897
# [81]	validation_0-rmse:59.68736
# [82]	validation_0-rmse:59.36301
# [83]	validation_0-rmse:59.05972
# [84]	validation_0-rmse:58.72130
# [85]	validation_0-rmse:58.39845
# [86]	validation_0-rmse:58.08075
# [87]	validation_0-rmse:57.77853
# [88]	validation_0-rmse:57.46843
# [89]	validation_0-rmse:57.14896
# [90]	validation_0-rmse:56.84361
# [91]	validation_0-rmse:56.53586
# [92]	validation_0-rmse:56.23892
# [93]	validation_0-rmse:55.94074
# [94]	validation_0-rmse:55.63619
# [95]	validation_0-rmse:55.33707
# [96]	validation_0-rmse:55.04718
# [97]	validation_0-rmse:54.77238
# [98]	validation_0-rmse:54.47891
# [99]	validation_0-rmse:54.17924
# [100]	validation_0-rmse:53.87137
# [101]	validation_0-rmse:53.59817
# [102]	validation_0-rmse:53.31675
# [103]	validation_0-rmse:53.03265
# [104]	validation_0-rmse:52.76202
# [105]	validation_0-rmse:52.49735
# [106]	validation_0-rmse:52.22709
# [107]	validation_0-rmse:51.95133
# [108]	validation_0-rmse:51.68690
# [109]	validation_0-rmse:51.42091
# [110]	validation_0-rmse:51.16302
# [111]	validation_0-rmse:50.88510
# [112]	validation_0-rmse:50.62473
# [113]	validation_0-rmse:50.35699
# [114]	validation_0-rmse:50.11193
# [115]	validation_0-rmse:49.84902
# [116]	validation_0-rmse:49.58695
# [117]	validation_0-rmse:49.32773
# [118]	validation_0-rmse:49.09888
# [119]	validation_0-rmse:48.86316
# [120]	validation_0-rmse:48.60894
# [121]	validation_0-rmse:48.34708
# [122]	validation_0-rmse:48.10207
# [123]	validation_0-rmse:47.86475
# [124]	validation_0-rmse:47.61598
# [125]	validation_0-rmse:47.36656
# [126]	validation_0-rmse:47.13195
# [127]	validation_0-rmse:46.90295
# [128]	validation_0-rmse:46.67787
# [129]	validation_0-rmse:46.44255
# [130]	validation_0-rmse:46.20243
# [131]	validation_0-rmse:45.98781
# [132]	validation_0-rmse:45.76033
# [133]	validation_0-rmse:45.53389
# [134]	validation_0-rmse:45.30298
# [135]	validation_0-rmse:45.07566
# [136]	validation_0-rmse:44.86233
# [137]	validation_0-rmse:44.62929
# [138]	validation_0-rmse:44.40952
# [139]	validation_0-rmse:44.19724
# [140]	validation_0-rmse:43.98025
# [141]	validation_0-rmse:43.76063
# [142]	validation_0-rmse:43.54863
# [143]	validation_0-rmse:43.34734
# [144]	validation_0-rmse:43.14225
# [145]	validation_0-rmse:42.92321
# [146]	validation_0-rmse:42.70860
# [147]	validation_0-rmse:42.50530
# [148]	validation_0-rmse:42.30207
# [149]	validation_0-rmse:42.09297
# [150]	validation_0-rmse:41.90092
# [151]	validation_0-rmse:41.70382
# [152]	validation_0-rmse:41.48971
# [153]	validation_0-rmse:41.30145
# [154]	validation_0-rmse:41.10858
# [155]	validation_0-rmse:40.91023
# [156]	validation_0-rmse:40.70824
# [157]	validation_0-rmse:40.52758
# [158]	validation_0-rmse:40.33217
# [159]	validation_0-rmse:40.15216
# [160]	validation_0-rmse:39.97597
# [161]	validation_0-rmse:39.78476
# [162]	validation_0-rmse:39.59508
# [163]	validation_0-rmse:39.40589
# [164]	validation_0-rmse:39.21019
# [165]	validation_0-rmse:39.03186
# [166]	validation_0-rmse:38.84109
# [167]	validation_0-rmse:38.66048
# [168]	validation_0-rmse:38.48475
# [169]	validation_0-rmse:38.31333
# [170]	validation_0-rmse:38.13415
# [171]	validation_0-rmse:37.95784
# [172]	validation_0-rmse:37.78851
# [173]	validation_0-rmse:37.62480
# [174]	validation_0-rmse:37.45935
# [175]	validation_0-rmse:37.29294
# [176]	validation_0-rmse:37.11781
# [177]	validation_0-rmse:36.96007
# [178]	validation_0-rmse:36.80783
# [179]	validation_0-rmse:36.63854
# [180]	validation_0-rmse:36.48736
# [181]	validation_0-rmse:36.33012
# [182]	validation_0-rmse:36.17786
# [183]	validation_0-rmse:36.01337
# [184]	validation_0-rmse:35.86363
# [185]	validation_0-rmse:35.70228
# [186]	validation_0-rmse:35.54844
# [187]	validation_0-rmse:35.40286
# [188]	validation_0-rmse:35.24639
# [189]	validation_0-rmse:35.08976
# [190]	validation_0-rmse:34.93338
# [191]	validation_0-rmse:34.79335
# [192]	validation_0-rmse:34.63512
# [193]	validation_0-rmse:34.50216
# [194]	validation_0-rmse:34.37005
# [195]	validation_0-rmse:34.21748
# [196]	validation_0-rmse:34.06642
# [197]	validation_0-rmse:33.93319
# [198]	validation_0-rmse:33.79292
# [199]	validation_0-rmse:33.65068
# [200]	validation_0-rmse:33.51173
# [201]	validation_0-rmse:33.39563
# [202]	validation_0-rmse:33.27113
# [203]	validation_0-rmse:33.13442
# [204]	validation_0-rmse:32.99957
# [205]	validation_0-rmse:32.87565
# [206]	validation_0-rmse:32.74109
# [207]	validation_0-rmse:32.62288
# [208]	validation_0-rmse:32.49740
# [209]	validation_0-rmse:32.37177
# [210]	validation_0-rmse:32.23711
# [211]	validation_0-rmse:32.12105
# [212]	validation_0-rmse:31.99793
# [213]	validation_0-rmse:31.88485
# [214]	validation_0-rmse:31.76877
# [215]	validation_0-rmse:31.65246
# [216]	validation_0-rmse:31.52683
# [217]	validation_0-rmse:31.40346
# [218]	validation_0-rmse:31.28988
# [219]	validation_0-rmse:31.18122
# [220]	validation_0-rmse:31.07386
# [221]	validation_0-rmse:30.95896
# [222]	validation_0-rmse:30.85241
# [223]	validation_0-rmse:30.74468
# [224]	validation_0-rmse:30.63733
# [225]	validation_0-rmse:30.53164
# [226]	validation_0-rmse:30.41336
# [227]	validation_0-rmse:30.30699
# [228]	validation_0-rmse:30.20085
# [229]	validation_0-rmse:30.10368
# [230]	validation_0-rmse:29.99474
# [231]	validation_0-rmse:29.88870
# [232]	validation_0-rmse:29.76912
# [233]	validation_0-rmse:29.66211
# [234]	validation_0-rmse:29.55421
# [235]	validation_0-rmse:29.45479
# [236]	validation_0-rmse:29.37407
# [237]	validation_0-rmse:29.26898
# [238]	validation_0-rmse:29.17036
# [239]	validation_0-rmse:29.08012
# [240]	validation_0-rmse:28.97597
# [241]	validation_0-rmse:28.88171
# [242]	validation_0-rmse:28.78916
# [243]	validation_0-rmse:28.69731
# [244]	validation_0-rmse:28.61112
# [245]	validation_0-rmse:28.51362
# [246]	validation_0-rmse:28.41855
# [247]	validation_0-rmse:28.32525
# [248]	validation_0-rmse:28.23486
# [249]	validation_0-rmse:28.14557
# [250]	validation_0-rmse:28.05156
# [251]	validation_0-rmse:27.95950
# [252]	validation_0-rmse:27.86735
# [253]	validation_0-rmse:27.78527
# [254]	validation_0-rmse:27.69504
# [255]	validation_0-rmse:27.58830
# [256]	validation_0-rmse:27.51170
# [257]	validation_0-rmse:27.43273
# [258]	validation_0-rmse:27.36377
# [259]	validation_0-rmse:27.27266
# [260]	validation_0-rmse:27.19137
# [261]	validation_0-rmse:27.10664
# [262]	validation_0-rmse:27.02393
# [263]	validation_0-rmse:26.94357
# [264]	validation_0-rmse:26.86552
# [265]	validation_0-rmse:26.78631
# [266]	validation_0-rmse:26.70172
# [267]	validation_0-rmse:26.61900
# [268]	validation_0-rmse:26.54654
# [269]	validation_0-rmse:26.47757
# [270]	validation_0-rmse:26.40043
# [271]	validation_0-rmse:26.33345
# [272]	validation_0-rmse:26.26703
# [273]	validation_0-rmse:26.19562
# [274]	validation_0-rmse:26.12405
# [275]	validation_0-rmse:26.04355
# [276]	validation_0-rmse:25.97163
# [277]	validation_0-rmse:25.90522
# [278]	validation_0-rmse:25.83622
# [279]	validation_0-rmse:25.76146
# [280]	validation_0-rmse:25.69974
# [281]	validation_0-rmse:25.63445
# [282]	validation_0-rmse:25.57423
# [283]	validation_0-rmse:25.50752
# [284]	validation_0-rmse:25.44530
# [285]	validation_0-rmse:25.38728
# [286]	validation_0-rmse:25.33560
# [287]	validation_0-rmse:25.27747
# [288]	validation_0-rmse:25.21451
# [289]	validation_0-rmse:25.15735
# [290]	validation_0-rmse:25.10076
# [291]	validation_0-rmse:25.03286
# [292]	validation_0-rmse:24.97157
# [293]	validation_0-rmse:24.91161
# [294]	validation_0-rmse:24.85613
# [295]	validation_0-rmse:24.79473
# [296]	validation_0-rmse:24.74144
# [297]	validation_0-rmse:24.67872
# [298]	validation_0-rmse:24.62313
# [299]	validation_0-rmse:24.56471
# [300]	validation_0-rmse:24.51684
# [301]	validation_0-rmse:24.45923
# [302]	validation_0-rmse:24.41167
# [303]	validation_0-rmse:24.35721
# [304]	validation_0-rmse:24.30608
# [305]	validation_0-rmse:24.25623
# [306]	validation_0-rmse:24.20490
# [307]	validation_0-rmse:24.15644
# [308]	validation_0-rmse:24.10401
# [309]	validation_0-rmse:24.06017
# [310]	validation_0-rmse:24.01472
# [311]	validation_0-rmse:23.97583
# [312]	validation_0-rmse:23.92752
# [313]	validation_0-rmse:23.87752
# [314]	validation_0-rmse:23.82989
# [315]	validation_0-rmse:23.78830
# [316]	validation_0-rmse:23.73844
# [317]	validation_0-rmse:23.68637
# [318]	validation_0-rmse:23.63983
# [319]	validation_0-rmse:23.60268
# [320]	validation_0-rmse:23.55496
# [321]	validation_0-rmse:23.51265
# [322]	validation_0-rmse:23.47123
# [323]	validation_0-rmse:23.42134
# [324]	validation_0-rmse:23.39033
# [325]	validation_0-rmse:23.34238
# [326]	validation_0-rmse:23.30203
# [327]	validation_0-rmse:23.26417
# [328]	validation_0-rmse:23.21890
# [329]	validation_0-rmse:23.17681
# [330]	validation_0-rmse:23.13741
# [331]	validation_0-rmse:23.10623
# [332]	validation_0-rmse:23.07453
# [333]	validation_0-rmse:23.03634
# [334]	validation_0-rmse:22.99379
# [335]	validation_0-rmse:22.96137
# [336]	validation_0-rmse:22.92966
# [337]	validation_0-rmse:22.89863
# [338]	validation_0-rmse:22.85790
# [339]	validation_0-rmse:22.82166
# [340]	validation_0-rmse:22.78254
# [341]	validation_0-rmse:22.75226
# [342]	validation_0-rmse:22.71493
# [343]	validation_0-rmse:22.68420
# [344]	validation_0-rmse:22.64756
# [345]	validation_0-rmse:22.62061
# [346]	validation_0-rmse:22.58429
# [347]	validation_0-rmse:22.55292
# [348]	validation_0-rmse:22.52163
# [349]	validation_0-rmse:22.48511
# [350]	validation_0-rmse:22.45847
# [351]	validation_0-rmse:22.43136
# [352]	validation_0-rmse:22.39742
# [353]	validation_0-rmse:22.37236
# [354]	validation_0-rmse:22.34520
# [355]	validation_0-rmse:22.32731
# [356]	validation_0-rmse:22.30012
# [357]	validation_0-rmse:22.26555
# [358]	validation_0-rmse:22.23891
# [359]	validation_0-rmse:22.21283
# [360]	validation_0-rmse:22.18751
# [361]	validation_0-rmse:22.16235
# [362]	validation_0-rmse:22.14172
# [363]	validation_0-rmse:22.11632
# [364]	validation_0-rmse:22.08447
# [365]	validation_0-rmse:22.05874
# [366]	validation_0-rmse:22.02868
# [367]	validation_0-rmse:21.99882
# [368]	validation_0-rmse:21.98137
# [369]	validation_0-rmse:21.95711
# [370]	validation_0-rmse:21.93470
# [371]	validation_0-rmse:21.90509
# [372]	validation_0-rmse:21.88222
# [373]	validation_0-rmse:21.86753
# [374]	validation_0-rmse:21.84046
# [375]	validation_0-rmse:21.82466
# [376]	validation_0-rmse:21.80507
# [377]	validation_0-rmse:21.78536
# [378]	validation_0-rmse:21.76508
# [379]	validation_0-rmse:21.74300
# [380]	validation_0-rmse:21.71559
# [381]	validation_0-rmse:21.69581
# [382]	validation_0-rmse:21.68428
# [383]	validation_0-rmse:21.66936
# [384]	validation_0-rmse:21.65050
# [385]	validation_0-rmse:21.63121
# [386]	validation_0-rmse:21.60487
# [387]	validation_0-rmse:21.58965
# [388]	validation_0-rmse:21.57117
# [389]	validation_0-rmse:21.55273
# [390]	validation_0-rmse:21.53201
# [391]	validation_0-rmse:21.52343
# [392]	validation_0-rmse:21.50872
# [393]	validation_0-rmse:21.48986
# [394]	validation_0-rmse:21.47623
# [395]	validation_0-rmse:21.46150
# [396]	validation_0-rmse:21.43621
# [397]	validation_0-rmse:21.42356
# [398]	validation_0-rmse:21.39356
# [399]	validation_0-rmse:21.37343
# [400]	validation_0-rmse:21.35855
# [401]	validation_0-rmse:21.34612
# [402]	validation_0-rmse:21.32842
# [403]	validation_0-rmse:21.31203
# [404]	validation_0-rmse:21.29774
# [405]	validation_0-rmse:21.28445
# [406]	validation_0-rmse:21.26670
# [407]	validation_0-rmse:21.25721
# [408]	validation_0-rmse:21.25064
# [409]	validation_0-rmse:21.24586
# [410]	validation_0-rmse:21.22712
# [411]	validation_0-rmse:21.21702
# [412]	validation_0-rmse:21.20767
# [413]	validation_0-rmse:21.18807
# [414]	validation_0-rmse:21.18008
# [415]	validation_0-rmse:21.16667
# [416]	validation_0-rmse:21.16075
# [417]	validation_0-rmse:21.14925
# [418]	validation_0-rmse:21.13762
# [419]	validation_0-rmse:21.12362
# [420]	validation_0-rmse:21.10758
# [421]	validation_0-rmse:21.09315
# [422]	validation_0-rmse:21.07960
# [423]	validation_0-rmse:21.07549
# [424]	validation_0-rmse:21.06350
# [425]	validation_0-rmse:21.05566
# [426]	validation_0-rmse:21.04273
# [427]	validation_0-rmse:21.03211
# [428]	validation_0-rmse:21.02332
# [429]	validation_0-rmse:21.02127
# [430]	validation_0-rmse:21.01645
# [431]	validation_0-rmse:21.00958
# [432]	validation_0-rmse:21.00246
# [433]	validation_0-rmse:20.99563
# [434]	validation_0-rmse:20.98512
# [435]	validation_0-rmse:20.97429
# [436]	validation_0-rmse:20.96611
# [437]	validation_0-rmse:20.95758
# [438]	validation_0-rmse:20.95476
# [439]	validation_0-rmse:20.95008
# [440]	validation_0-rmse:20.94258
# [441]	validation_0-rmse:20.93335
# [442]	validation_0-rmse:20.92896
# [443]	validation_0-rmse:20.91687
# [444]	validation_0-rmse:20.91122
# [445]	validation_0-rmse:20.90649
# [446]	validation_0-rmse:20.89716
# [447]	validation_0-rmse:20.89102
# [448]	validation_0-rmse:20.88486
# [449]	validation_0-rmse:20.87354
# [450]	validation_0-rmse:20.85982
# [451]	validation_0-rmse:20.85012
# [452]	validation_0-rmse:20.83614
# [453]	validation_0-rmse:20.83014
# [454]	validation_0-rmse:20.82568
# [455]	validation_0-rmse:20.81662
# [456]	validation_0-rmse:20.81132
# [457]	validation_0-rmse:20.80620
# [458]	validation_0-rmse:20.80113
# [459]	validation_0-rmse:20.79562
# [460]	validation_0-rmse:20.78606
# [461]	validation_0-rmse:20.77812
# [462]	validation_0-rmse:20.76634
# [463]	validation_0-rmse:20.76190
# [464]	validation_0-rmse:20.75873
# [465]	validation_0-rmse:20.75411
# [466]	validation_0-rmse:20.74398
# [467]	validation_0-rmse:20.73594
# [468]	validation_0-rmse:20.73126
# [469]	validation_0-rmse:20.72610
# [470]	validation_0-rmse:20.72126
# [471]	validation_0-rmse:20.72005
# [472]	validation_0-rmse:20.71615
# [473]	validation_0-rmse:20.71736
# [474]	validation_0-rmse:20.70864
# [475]	validation_0-rmse:20.70341
# [476]	validation_0-rmse:20.69618
# [477]	validation_0-rmse:20.69526
# [478]	validation_0-rmse:20.69401
# [479]	validation_0-rmse:20.69099
# [480]	validation_0-rmse:20.68521
# [481]	validation_0-rmse:20.68529
# [482]	validation_0-rmse:20.68704
# [483]	validation_0-rmse:20.68413
# [484]	validation_0-rmse:20.68796
# [485]	validation_0-rmse:20.68089
# [486]	validation_0-rmse:20.67876
# [487]	validation_0-rmse:20.67605
# [488]	validation_0-rmse:20.67713
# [489]	validation_0-rmse:20.67373
# [490]	validation_0-rmse:20.67216
# [491]	validation_0-rmse:20.67043
# [492]	validation_0-rmse:20.68242
# [493]	validation_0-rmse:20.67978
# [494]	validation_0-rmse:20.67391
# [495]	validation_0-rmse:20.66477
# [496]	validation_0-rmse:20.65883
# [497]	validation_0-rmse:20.65423
# [498]	validation_0-rmse:20.64979
# [499]	validation_0-rmse:20.64741
# [500]	validation_0-rmse:20.64668
# [501]	validation_0-rmse:20.65211
# [502]	validation_0-rmse:20.64971
# [503]	validation_0-rmse:20.64425
# [504]	validation_0-rmse:20.64002
# [505]	validation_0-rmse:20.63797
# [506]	validation_0-rmse:20.64481
# [507]	validation_0-rmse:20.65205
# [508]	validation_0-rmse:20.65653
# [509]	validation_0-rmse:20.65263
# [510]	validation_0-rmse:20.65781
# [511]	validation_0-rmse:20.67094
# [512]	validation_0-rmse:20.66700
# [513]	validation_0-rmse:20.66072
# [514]	validation_0-rmse:20.66029
# [515]	validation_0-rmse:20.66014
# [516]	validation_0-rmse:20.65847
# [517]	validation_0-rmse:20.65983
# [518]	validation_0-rmse:20.66082
# [519]	validation_0-rmse:20.66266
# [520]	validation_0-rmse:20.67178
# [521]	validation_0-rmse:20.68187
# [522]	validation_0-rmse:20.68145
# [523]	validation_0-rmse:20.68753
# [524]	validation_0-rmse:20.69187
# [525]	validation_0-rmse:20.69417
# [526]	validation_0-rmse:20.69224
# [527]	validation_0-rmse:20.68996
# [528]	validation_0-rmse:20.69180
# [529]	validation_0-rmse:20.69032
# [530]	validation_0-rmse:20.69360
# [531]	validation_0-rmse:20.69635
# [532]	validation_0-rmse:20.69387
# [533]	validation_0-rmse:20.69490
# [534]	validation_0-rmse:20.69414
# [535]	validation_0-rmse:20.69857
# [536]	validation_0-rmse:20.69679
# [537]	validation_0-rmse:20.69716
# [538]	validation_0-rmse:20.69356
# [539]	validation_0-rmse:20.69550
# [540]	validation_0-rmse:20.69452
# [541]	validation_0-rmse:20.69360
# [542]	validation_0-rmse:20.69206
# [543]	validation_0-rmse:20.70303
# [544]	validation_0-rmse:20.70272
# [545]	validation_0-rmse:20.70501
# [546]	validation_0-rmse:20.70405
# [547]	validation_0-rmse:20.70447
# [548]	validation_0-rmse:20.70855
# [549]	validation_0-rmse:20.70793
# [550]	validation_0-rmse:20.71113
# [551]	validation_0-rmse:20.71253
# [552]	validation_0-rmse:20.71538
# [553]	validation_0-rmse:20.71555
# [554]	validation_0-rmse:20.71573
# [555]	validation_0-rmse:20.71420
# [556]	validation_0-rmse:20.71603
# [557]	validation_0-rmse:20.72046
# [558]	validation_0-rmse:20.72424
# [559]	validation_0-rmse:20.72599
# [560]	validation_0-rmse:20.73245
# [561]	validation_0-rmse:20.73396
# [562]	validation_0-rmse:20.73679
# [563]	validation_0-rmse:20.73613
# [564]	validation_0-rmse:20.73201
# [565]	validation_0-rmse:20.73254
# [566]	validation_0-rmse:20.73496
# [567]	validation_0-rmse:20.73568
# [568]	validation_0-rmse:20.73978
# [569]	validation_0-rmse:20.74546
# [570]	validation_0-rmse:20.74707
# [571]	validation_0-rmse:20.74832
# [572]	validation_0-rmse:20.75048
# [573]	validation_0-rmse:20.75470
# [574]	validation_0-rmse:20.75170
# [575]	validation_0-rmse:20.76368
# [576]	validation_0-rmse:20.76353
# [577]	validation_0-rmse:20.76666
# [578]	validation_0-rmse:20.76762
# [579]	validation_0-rmse:20.76857
# [580]	validation_0-rmse:20.77845
# [581]	validation_0-rmse:20.78306
# [582]	validation_0-rmse:20.78875
# [583]	validation_0-rmse:20.78955
# [584]	validation_0-rmse:20.79597
# [585]	validation_0-rmse:20.80172
# Linear Regression RMSE: 59.55553754229708
# XGBoost RMSE: 37.764083400442885
# --------------------------------------------------------
#
# Date to predict:  2025-01-08 00:00:00
# [0]	validation_0-rmse:91.75468
# [1]	validation_0-rmse:91.22690
# [2]	validation_0-rmse:90.70986
# [3]	validation_0-rmse:90.19386
# [4]	validation_0-rmse:89.65310
# [5]	validation_0-rmse:89.13409
# [6]	validation_0-rmse:88.61832
# [7]	validation_0-rmse:88.10975
# [8]	validation_0-rmse:87.59403
# [9]	validation_0-rmse:87.09844
# [10]	validation_0-rmse:86.61431
# [11]	validation_0-rmse:86.11701
# [12]	validation_0-rmse:85.62863
# [13]	validation_0-rmse:85.13148
# [14]	validation_0-rmse:84.67459
# [15]	validation_0-rmse:84.20261
# [16]	validation_0-rmse:83.73974
# [17]	validation_0-rmse:83.26321
# [18]	validation_0-rmse:82.77039
# [19]	validation_0-rmse:82.28384
# [20]	validation_0-rmse:81.79393
# [21]	validation_0-rmse:81.33777
# [22]	validation_0-rmse:80.87880
# [23]	validation_0-rmse:80.41269
# [24]	validation_0-rmse:79.94714
# [25]	validation_0-rmse:79.48972
# [26]	validation_0-rmse:79.03177
# [27]	validation_0-rmse:78.58566
# [28]	validation_0-rmse:78.14658
# [29]	validation_0-rmse:77.70214
# [30]	validation_0-rmse:77.28345
# [31]	validation_0-rmse:76.84704
# [32]	validation_0-rmse:76.42630
# [33]	validation_0-rmse:75.99670
# [34]	validation_0-rmse:75.57194
# [35]	validation_0-rmse:75.15434
# [36]	validation_0-rmse:74.71389
# [37]	validation_0-rmse:74.28694
# [38]	validation_0-rmse:73.87391
# [39]	validation_0-rmse:73.46637
# [40]	validation_0-rmse:73.06023
# [41]	validation_0-rmse:72.65195
# [42]	validation_0-rmse:72.25042
# [43]	validation_0-rmse:71.84779
# [44]	validation_0-rmse:71.43740
# [45]	validation_0-rmse:71.01919
# [46]	validation_0-rmse:70.62918
# [47]	validation_0-rmse:70.23313
# [48]	validation_0-rmse:69.84870
# [49]	validation_0-rmse:69.44634
# [50]	validation_0-rmse:69.06732
# [51]	validation_0-rmse:68.70049
# [52]	validation_0-rmse:68.30823
# [53]	validation_0-rmse:67.92085
# [54]	validation_0-rmse:67.53871
# [55]	validation_0-rmse:67.18180
# [56]	validation_0-rmse:66.81401
# [57]	validation_0-rmse:66.42958
# [58]	validation_0-rmse:66.05519
# [59]	validation_0-rmse:65.71994
# [60]	validation_0-rmse:65.34655
# [61]	validation_0-rmse:64.99008
# [62]	validation_0-rmse:64.61641
# [63]	validation_0-rmse:64.27258
# [64]	validation_0-rmse:63.90596
# [65]	validation_0-rmse:63.55314
# [66]	validation_0-rmse:63.19087
# [67]	validation_0-rmse:62.84136
# [68]	validation_0-rmse:62.49173
# [69]	validation_0-rmse:62.14101
# [70]	validation_0-rmse:61.78682
# [71]	validation_0-rmse:61.45046
# [72]	validation_0-rmse:61.10917
# [73]	validation_0-rmse:60.77114
# [74]	validation_0-rmse:60.44492
# [75]	validation_0-rmse:60.12303
# [76]	validation_0-rmse:59.80571
# [77]	validation_0-rmse:59.49696
# [78]	validation_0-rmse:59.17956
# [79]	validation_0-rmse:58.85799
# [80]	validation_0-rmse:58.54077
# [81]	validation_0-rmse:58.23900
# [82]	validation_0-rmse:57.93796
# [83]	validation_0-rmse:57.63442
# [84]	validation_0-rmse:57.31480
# [85]	validation_0-rmse:57.00501
# [86]	validation_0-rmse:56.69169
# [87]	validation_0-rmse:56.38029
# [88]	validation_0-rmse:56.07485
# [89]	validation_0-rmse:55.77859
# [90]	validation_0-rmse:55.48841
# [91]	validation_0-rmse:55.17721
# [92]	validation_0-rmse:54.87179
# [93]	validation_0-rmse:54.57827
# [94]	validation_0-rmse:54.29666
# [95]	validation_0-rmse:54.01148
# [96]	validation_0-rmse:53.74593
# [97]	validation_0-rmse:53.47118
# [98]	validation_0-rmse:53.18465
# [99]	validation_0-rmse:52.90044
# [100]	validation_0-rmse:52.60595
# [101]	validation_0-rmse:52.34179
# [102]	validation_0-rmse:52.06198
# [103]	validation_0-rmse:51.80281
# [104]	validation_0-rmse:51.52565
# [105]	validation_0-rmse:51.25876
# [106]	validation_0-rmse:50.97555
# [107]	validation_0-rmse:50.72246
# [108]	validation_0-rmse:50.45338
# [109]	validation_0-rmse:50.19598
# [110]	validation_0-rmse:49.94915
# [111]	validation_0-rmse:49.70140
# [112]	validation_0-rmse:49.44325
# [113]	validation_0-rmse:49.17740
# [114]	validation_0-rmse:48.91707
# [115]	validation_0-rmse:48.67037
# [116]	validation_0-rmse:48.42539
# [117]	validation_0-rmse:48.17991
# [118]	validation_0-rmse:47.94146
# [119]	validation_0-rmse:47.67337
# [120]	validation_0-rmse:47.41880
# [121]	validation_0-rmse:47.16693
# [122]	validation_0-rmse:46.93200
# [123]	validation_0-rmse:46.70347
# [124]	validation_0-rmse:46.48158
# [125]	validation_0-rmse:46.25881
# [126]	validation_0-rmse:46.02678
# [127]	validation_0-rmse:45.79611
# [128]	validation_0-rmse:45.56195
# [129]	validation_0-rmse:45.33844
# [130]	validation_0-rmse:45.11272
# [131]	validation_0-rmse:44.87635
# [132]	validation_0-rmse:44.66457
# [133]	validation_0-rmse:44.44407
# [134]	validation_0-rmse:44.23300
# [135]	validation_0-rmse:44.00060
# [136]	validation_0-rmse:43.78891
# [137]	validation_0-rmse:43.57610
# [138]	validation_0-rmse:43.35814
# [139]	validation_0-rmse:43.14290
# [140]	validation_0-rmse:42.93556
# [141]	validation_0-rmse:42.74012
# [142]	validation_0-rmse:42.54539
# [143]	validation_0-rmse:42.34092
# [144]	validation_0-rmse:42.12277
# [145]	validation_0-rmse:41.91728
# [146]	validation_0-rmse:41.72000
# [147]	validation_0-rmse:41.53823
# [148]	validation_0-rmse:41.34176
# [149]	validation_0-rmse:41.15050
# [150]	validation_0-rmse:40.95272
# [151]	validation_0-rmse:40.76936
# [152]	validation_0-rmse:40.57508
# [153]	validation_0-rmse:40.39080
# [154]	validation_0-rmse:40.21637
# [155]	validation_0-rmse:40.03554
# [156]	validation_0-rmse:39.85801
# [157]	validation_0-rmse:39.67403
# [158]	validation_0-rmse:39.48951
# [159]	validation_0-rmse:39.31209
# [160]	validation_0-rmse:39.12256
# [161]	validation_0-rmse:38.93972
# [162]	validation_0-rmse:38.76175
# [163]	validation_0-rmse:38.58478
# [164]	validation_0-rmse:38.39022
# [165]	validation_0-rmse:38.22172
# [166]	validation_0-rmse:38.02523
# [167]	validation_0-rmse:37.83955
# [168]	validation_0-rmse:37.67695
# [169]	validation_0-rmse:37.50707
# [170]	validation_0-rmse:37.34515
# [171]	validation_0-rmse:37.17921
# [172]	validation_0-rmse:37.00756
# [173]	validation_0-rmse:36.83644
# [174]	validation_0-rmse:36.67769
# [175]	validation_0-rmse:36.52004
# [176]	validation_0-rmse:36.34927
# [177]	validation_0-rmse:36.17810
# [178]	validation_0-rmse:36.00512
# [179]	validation_0-rmse:35.84832
# [180]	validation_0-rmse:35.69854
# [181]	validation_0-rmse:35.54812
# [182]	validation_0-rmse:35.39837
# [183]	validation_0-rmse:35.25554
# [184]	validation_0-rmse:35.10851
# [185]	validation_0-rmse:34.95395
# [186]	validation_0-rmse:34.79053
# [187]	validation_0-rmse:34.64702
# [188]	validation_0-rmse:34.50735
# [189]	validation_0-rmse:34.36616
# [190]	validation_0-rmse:34.22723
# [191]	validation_0-rmse:34.07552
# [192]	validation_0-rmse:33.92550
# [193]	validation_0-rmse:33.78068
# [194]	validation_0-rmse:33.64115
# [195]	validation_0-rmse:33.49431
# [196]	validation_0-rmse:33.35591
# [197]	validation_0-rmse:33.21597
# [198]	validation_0-rmse:33.08669
# [199]	validation_0-rmse:32.97116
# [200]	validation_0-rmse:32.83767
# [201]	validation_0-rmse:32.70867
# [202]	validation_0-rmse:32.58274
# [203]	validation_0-rmse:32.45418
# [204]	validation_0-rmse:32.33559
# [205]	validation_0-rmse:32.21496
# [206]	validation_0-rmse:32.08046
# [207]	validation_0-rmse:31.95559
# [208]	validation_0-rmse:31.82526
# [209]	validation_0-rmse:31.69099
# [210]	validation_0-rmse:31.55931
# [211]	validation_0-rmse:31.43836
# [212]	validation_0-rmse:31.31721
# [213]	validation_0-rmse:31.19468
# [214]	validation_0-rmse:31.08318
# [215]	validation_0-rmse:30.97555
# [216]	validation_0-rmse:30.86096
# [217]	validation_0-rmse:30.74549
# [218]	validation_0-rmse:30.63083
# [219]	validation_0-rmse:30.50942
# [220]	validation_0-rmse:30.39224
# [221]	validation_0-rmse:30.28251
# [222]	validation_0-rmse:30.19271
# [223]	validation_0-rmse:30.08768
# [224]	validation_0-rmse:29.98032
# [225]	validation_0-rmse:29.88069
# [226]	validation_0-rmse:29.77086
# [227]	validation_0-rmse:29.66398
# [228]	validation_0-rmse:29.55436
# [229]	validation_0-rmse:29.45161
# [230]	validation_0-rmse:29.35413
# [231]	validation_0-rmse:29.26241
# [232]	validation_0-rmse:29.16428
# [233]	validation_0-rmse:29.06673
# [234]	validation_0-rmse:28.95515
# [235]	validation_0-rmse:28.86341
# [236]	validation_0-rmse:28.77103
# [237]	validation_0-rmse:28.66828
# [238]	validation_0-rmse:28.57377
# [239]	validation_0-rmse:28.47549
# [240]	validation_0-rmse:28.38211
# [241]	validation_0-rmse:28.29017
# [242]	validation_0-rmse:28.21106
# [243]	validation_0-rmse:28.12803
# [244]	validation_0-rmse:28.04833
# [245]	validation_0-rmse:27.95266
# [246]	validation_0-rmse:27.86402
# [247]	validation_0-rmse:27.78431
# [248]	validation_0-rmse:27.69081
# [249]	validation_0-rmse:27.60795
# [250]	validation_0-rmse:27.51606
# [251]	validation_0-rmse:27.42370
# [252]	validation_0-rmse:27.34375
# [253]	validation_0-rmse:27.26723
# [254]	validation_0-rmse:27.18899
# [255]	validation_0-rmse:27.10304
# [256]	validation_0-rmse:27.02637
# [257]	validation_0-rmse:26.94039
# [258]	validation_0-rmse:26.86333
# [259]	validation_0-rmse:26.77907
# [260]	validation_0-rmse:26.70465
# [261]	validation_0-rmse:26.63176
# [262]	validation_0-rmse:26.54895
# [263]	validation_0-rmse:26.47248
# [264]	validation_0-rmse:26.40234
# [265]	validation_0-rmse:26.33436
# [266]	validation_0-rmse:26.25893
# [267]	validation_0-rmse:26.18909
# [268]	validation_0-rmse:26.11628
# [269]	validation_0-rmse:26.05106
# [270]	validation_0-rmse:25.99308
# [271]	validation_0-rmse:25.91911
# [272]	validation_0-rmse:25.84968
# [273]	validation_0-rmse:25.78903
# [274]	validation_0-rmse:25.72348
# [275]	validation_0-rmse:25.65863
# [276]	validation_0-rmse:25.59703
# [277]	validation_0-rmse:25.53436
# [278]	validation_0-rmse:25.48071
# [279]	validation_0-rmse:25.40476
# [280]	validation_0-rmse:25.33620
# [281]	validation_0-rmse:25.28235
# [282]	validation_0-rmse:25.22331
# [283]	validation_0-rmse:25.17216
# [284]	validation_0-rmse:25.12234
# [285]	validation_0-rmse:25.06729
# [286]	validation_0-rmse:24.99830
# [287]	validation_0-rmse:24.94159
# [288]	validation_0-rmse:24.88294
# [289]	validation_0-rmse:24.82401
# [290]	validation_0-rmse:24.76430
# [291]	validation_0-rmse:24.70441
# [292]	validation_0-rmse:24.64198
# [293]	validation_0-rmse:24.58205
# [294]	validation_0-rmse:24.52608
# [295]	validation_0-rmse:24.46832
# [296]	validation_0-rmse:24.42130
# [297]	validation_0-rmse:24.37324
# [298]	validation_0-rmse:24.31795
# [299]	validation_0-rmse:24.27687
# [300]	validation_0-rmse:24.23038
# [301]	validation_0-rmse:24.18449
# [302]	validation_0-rmse:24.12976
# [303]	validation_0-rmse:24.07947
# [304]	validation_0-rmse:24.02993
# [305]	validation_0-rmse:23.98540
# [306]	validation_0-rmse:23.94377
# [307]	validation_0-rmse:23.90232
# [308]	validation_0-rmse:23.85027
# [309]	validation_0-rmse:23.79783
# [310]	validation_0-rmse:23.74825
# [311]	validation_0-rmse:23.69641
# [312]	validation_0-rmse:23.64679
# [313]	validation_0-rmse:23.59833
# [314]	validation_0-rmse:23.56495
# [315]	validation_0-rmse:23.52234
# [316]	validation_0-rmse:23.47629
# [317]	validation_0-rmse:23.42844
# [318]	validation_0-rmse:23.38982
# [319]	validation_0-rmse:23.34088
# [320]	validation_0-rmse:23.30483
# [321]	validation_0-rmse:23.27188
# [322]	validation_0-rmse:23.23176
# [323]	validation_0-rmse:23.19103
# [324]	validation_0-rmse:23.14832
# [325]	validation_0-rmse:23.10750
# [326]	validation_0-rmse:23.07279
# [327]	validation_0-rmse:23.03567
# [328]	validation_0-rmse:22.99763
# [329]	validation_0-rmse:22.95574
# [330]	validation_0-rmse:22.92662
# [331]	validation_0-rmse:22.88822
# [332]	validation_0-rmse:22.84954
# [333]	validation_0-rmse:22.80993
# [334]	validation_0-rmse:22.77993
# [335]	validation_0-rmse:22.74580
# [336]	validation_0-rmse:22.71710
# [337]	validation_0-rmse:22.68049
# [338]	validation_0-rmse:22.64336
# [339]	validation_0-rmse:22.60942
# [340]	validation_0-rmse:22.57431
# [341]	validation_0-rmse:22.53218
# [342]	validation_0-rmse:22.49746
# [343]	validation_0-rmse:22.46767
# [344]	validation_0-rmse:22.42884
# [345]	validation_0-rmse:22.40760
# [346]	validation_0-rmse:22.38162
# [347]	validation_0-rmse:22.35379
# [348]	validation_0-rmse:22.32516
# [349]	validation_0-rmse:22.28108
# [350]	validation_0-rmse:22.25178
# [351]	validation_0-rmse:22.22581
# [352]	validation_0-rmse:22.19513
# [353]	validation_0-rmse:22.17493
# [354]	validation_0-rmse:22.14911
# [355]	validation_0-rmse:22.10804
# [356]	validation_0-rmse:22.08024
# [357]	validation_0-rmse:22.04999
# [358]	validation_0-rmse:22.02265
# [359]	validation_0-rmse:21.99319
# [360]	validation_0-rmse:21.96576
# [361]	validation_0-rmse:21.93978
# [362]	validation_0-rmse:21.91892
# [363]	validation_0-rmse:21.88832
# [364]	validation_0-rmse:21.86620
# [365]	validation_0-rmse:21.83719
# [366]	validation_0-rmse:21.81577
# [367]	validation_0-rmse:21.79405
# [368]	validation_0-rmse:21.77033
# [369]	validation_0-rmse:21.74101
# [370]	validation_0-rmse:21.72493
# [371]	validation_0-rmse:21.70490
# [372]	validation_0-rmse:21.68298
# [373]	validation_0-rmse:21.66940
# [374]	validation_0-rmse:21.65108
# [375]	validation_0-rmse:21.63299
# [376]	validation_0-rmse:21.61179
# [377]	validation_0-rmse:21.59576
# [378]	validation_0-rmse:21.57967
# [379]	validation_0-rmse:21.55472
# [380]	validation_0-rmse:21.53476
# [381]	validation_0-rmse:21.50872
# [382]	validation_0-rmse:21.48858
# [383]	validation_0-rmse:21.47176
# [384]	validation_0-rmse:21.45439
# [385]	validation_0-rmse:21.43471
# [386]	validation_0-rmse:21.40425
# [387]	validation_0-rmse:21.38260
# [388]	validation_0-rmse:21.36478
# [389]	validation_0-rmse:21.34020
# [390]	validation_0-rmse:21.32465
# [391]	validation_0-rmse:21.31055
# [392]	validation_0-rmse:21.29563
# [393]	validation_0-rmse:21.27880
# [394]	validation_0-rmse:21.25952
# [395]	validation_0-rmse:21.24807
# [396]	validation_0-rmse:21.23868
# [397]	validation_0-rmse:21.22456
# [398]	validation_0-rmse:21.20236
# [399]	validation_0-rmse:21.18808
# [400]	validation_0-rmse:21.17397
# [401]	validation_0-rmse:21.15945
# [402]	validation_0-rmse:21.14421
# [403]	validation_0-rmse:21.12799
# [404]	validation_0-rmse:21.11557
# [405]	validation_0-rmse:21.10566
# [406]	validation_0-rmse:21.08913
# [407]	validation_0-rmse:21.07831
# [408]	validation_0-rmse:21.06679
# [409]	validation_0-rmse:21.05424
# [410]	validation_0-rmse:21.04624
# [411]	validation_0-rmse:21.03695
# [412]	validation_0-rmse:21.03000
# [413]	validation_0-rmse:21.01692
# [414]	validation_0-rmse:21.00135
# [415]	validation_0-rmse:20.99505
# [416]	validation_0-rmse:20.99187
# [417]	validation_0-rmse:20.98269
# [418]	validation_0-rmse:20.96880
# [419]	validation_0-rmse:20.95791
# [420]	validation_0-rmse:20.94403
# [421]	validation_0-rmse:20.93721
# [422]	validation_0-rmse:20.92187
# [423]	validation_0-rmse:20.91148
# [424]	validation_0-rmse:20.89868
# [425]	validation_0-rmse:20.89137
# [426]	validation_0-rmse:20.88094
# [427]	validation_0-rmse:20.87423
# [428]	validation_0-rmse:20.85911
# [429]	validation_0-rmse:20.85155
# [430]	validation_0-rmse:20.84793
# [431]	validation_0-rmse:20.83908
# [432]	validation_0-rmse:20.82652
# [433]	validation_0-rmse:20.81942
# [434]	validation_0-rmse:20.80890
# [435]	validation_0-rmse:20.79627
# [436]	validation_0-rmse:20.78563
# [437]	validation_0-rmse:20.77805
# [438]	validation_0-rmse:20.77275
# [439]	validation_0-rmse:20.76290
# [440]	validation_0-rmse:20.76158
# [441]	validation_0-rmse:20.75823
# [442]	validation_0-rmse:20.75474
# [443]	validation_0-rmse:20.74444
# [444]	validation_0-rmse:20.73691
# [445]	validation_0-rmse:20.73320
# [446]	validation_0-rmse:20.73071
# [447]	validation_0-rmse:20.71684
# [448]	validation_0-rmse:20.71175
# [449]	validation_0-rmse:20.70313
# [450]	validation_0-rmse:20.68320
# [451]	validation_0-rmse:20.67925
# [452]	validation_0-rmse:20.67470
# [453]	validation_0-rmse:20.67105
# [454]	validation_0-rmse:20.67280
# [455]	validation_0-rmse:20.66310
# [456]	validation_0-rmse:20.65218
# [457]	validation_0-rmse:20.64462
# [458]	validation_0-rmse:20.63487
# [459]	validation_0-rmse:20.63014
# [460]	validation_0-rmse:20.62248
# [461]	validation_0-rmse:20.61981
# [462]	validation_0-rmse:20.61627
# [463]	validation_0-rmse:20.60671
# [464]	validation_0-rmse:20.60709
# [465]	validation_0-rmse:20.60603
# [466]	validation_0-rmse:20.60605
# [467]	validation_0-rmse:20.60291
# [468]	validation_0-rmse:20.59959
# [469]	validation_0-rmse:20.58785
# [470]	validation_0-rmse:20.58487
# [471]	validation_0-rmse:20.57971
# [472]	validation_0-rmse:20.58048
# [473]	validation_0-rmse:20.57926
# [474]	validation_0-rmse:20.58225
# [475]	validation_0-rmse:20.57806
# [476]	validation_0-rmse:20.57603
# [477]	validation_0-rmse:20.57120
# [478]	validation_0-rmse:20.57037
# [479]	validation_0-rmse:20.56959
# [480]	validation_0-rmse:20.56904
# [481]	validation_0-rmse:20.57260
# [482]	validation_0-rmse:20.57359
# [483]	validation_0-rmse:20.57588
# [484]	validation_0-rmse:20.57813
# [485]	validation_0-rmse:20.57528
# [486]	validation_0-rmse:20.57899
# [487]	validation_0-rmse:20.58111
# [488]	validation_0-rmse:20.57832
# [489]	validation_0-rmse:20.57829
# [490]	validation_0-rmse:20.57373
# [491]	validation_0-rmse:20.57251
# [492]	validation_0-rmse:20.57746
# [493]	validation_0-rmse:20.57870
# [494]	validation_0-rmse:20.57867
# [495]	validation_0-rmse:20.57622
# [496]	validation_0-rmse:20.57622
# [497]	validation_0-rmse:20.57799
# [498]	validation_0-rmse:20.58240
# [499]	validation_0-rmse:20.58477
# [500]	validation_0-rmse:20.58021
# [501]	validation_0-rmse:20.57822
# [502]	validation_0-rmse:20.57049
# [503]	validation_0-rmse:20.57535
# [504]	validation_0-rmse:20.57896
# [505]	validation_0-rmse:20.57708
# [506]	validation_0-rmse:20.57377
# [507]	validation_0-rmse:20.57609
# [508]	validation_0-rmse:20.57687
# [509]	validation_0-rmse:20.57588
# [510]	validation_0-rmse:20.57510
# [511]	validation_0-rmse:20.57167
# [512]	validation_0-rmse:20.57271
# [513]	validation_0-rmse:20.57165
# [514]	validation_0-rmse:20.57274
# [515]	validation_0-rmse:20.57664
# [516]	validation_0-rmse:20.57228
# [517]	validation_0-rmse:20.57274
# [518]	validation_0-rmse:20.57257
# [519]	validation_0-rmse:20.57086
# [520]	validation_0-rmse:20.57091
# [521]	validation_0-rmse:20.57559
# [522]	validation_0-rmse:20.57577
# [523]	validation_0-rmse:20.57664
# [524]	validation_0-rmse:20.57964
# [525]	validation_0-rmse:20.58284
# [526]	validation_0-rmse:20.58010
# [527]	validation_0-rmse:20.58371
# [528]	validation_0-rmse:20.58029
# [529]	validation_0-rmse:20.58503
# [530]	validation_0-rmse:20.58413
# [531]	validation_0-rmse:20.58492
# [532]	validation_0-rmse:20.58486
# [533]	validation_0-rmse:20.58567
# [534]	validation_0-rmse:20.58130
# [535]	validation_0-rmse:20.58041
# [536]	validation_0-rmse:20.58261
# [537]	validation_0-rmse:20.58409
# [538]	validation_0-rmse:20.58457
# [539]	validation_0-rmse:20.58955
# [540]	validation_0-rmse:20.58577
# [541]	validation_0-rmse:20.59007
# [542]	validation_0-rmse:20.58925
# [543]	validation_0-rmse:20.59126
# [544]	validation_0-rmse:20.59362
# [545]	validation_0-rmse:20.59486
# [546]	validation_0-rmse:20.59402
# [547]	validation_0-rmse:20.59538
# [548]	validation_0-rmse:20.59720
# [549]	validation_0-rmse:20.59624
# [550]	validation_0-rmse:20.59692
# [551]	validation_0-rmse:20.59829
# [552]	validation_0-rmse:20.60244
# [553]	validation_0-rmse:20.60307
# [554]	validation_0-rmse:20.59347
# [555]	validation_0-rmse:20.59215
# [556]	validation_0-rmse:20.59831
# [557]	validation_0-rmse:20.59962
# [558]	validation_0-rmse:20.60454
# [559]	validation_0-rmse:20.61567
# [560]	validation_0-rmse:20.62398
# Linear Regression RMSE: 54.780321349498394
# XGBoost RMSE: 43.02466810248761
# --------------------------------------------------------
#
# Date to predict:  2025-01-09 00:00:00
# [0]	validation_0-rmse:92.46155
# [1]	validation_0-rmse:91.93292
# [2]	validation_0-rmse:91.38362
# [3]	validation_0-rmse:90.86617
# [4]	validation_0-rmse:90.33522
# [5]	validation_0-rmse:89.82735
# [6]	validation_0-rmse:89.30623
# [7]	validation_0-rmse:88.79293
# [8]	validation_0-rmse:88.29908
# [9]	validation_0-rmse:87.80564
# [10]	validation_0-rmse:87.32475
# [11]	validation_0-rmse:86.83009
# [12]	validation_0-rmse:86.31894
# [13]	validation_0-rmse:85.81919
# [14]	validation_0-rmse:85.34465
# [15]	validation_0-rmse:84.86901
# [16]	validation_0-rmse:84.39612
# [17]	validation_0-rmse:83.91368
# [18]	validation_0-rmse:83.41760
# [19]	validation_0-rmse:82.94020
# [20]	validation_0-rmse:82.47189
# [21]	validation_0-rmse:82.01429
# [22]	validation_0-rmse:81.55095
# [23]	validation_0-rmse:81.09131
# [24]	validation_0-rmse:80.65809
# [25]	validation_0-rmse:80.21237
# [26]	validation_0-rmse:79.76190
# [27]	validation_0-rmse:79.31870
# [28]	validation_0-rmse:78.87798
# [29]	validation_0-rmse:78.42968
# [30]	validation_0-rmse:77.99563
# [31]	validation_0-rmse:77.55802
# [32]	validation_0-rmse:77.10733
# [33]	validation_0-rmse:76.66759
# [34]	validation_0-rmse:76.25366
# [35]	validation_0-rmse:75.85212
# [36]	validation_0-rmse:75.42873
# [37]	validation_0-rmse:75.01503
# [38]	validation_0-rmse:74.61136
# [39]	validation_0-rmse:74.20254
# [40]	validation_0-rmse:73.78870
# [41]	validation_0-rmse:73.38415
# [42]	validation_0-rmse:72.97002
# [43]	validation_0-rmse:72.56026
# [44]	validation_0-rmse:72.17261
# [45]	validation_0-rmse:71.76200
# [46]	validation_0-rmse:71.38190
# [47]	validation_0-rmse:70.98990
# [48]	validation_0-rmse:70.60427
# [49]	validation_0-rmse:70.21499
# [50]	validation_0-rmse:69.83709
# [51]	validation_0-rmse:69.46925
# [52]	validation_0-rmse:69.10136
# [53]	validation_0-rmse:68.72035
# [54]	validation_0-rmse:68.34371
# [55]	validation_0-rmse:67.99648
# [56]	validation_0-rmse:67.62774
# [57]	validation_0-rmse:67.28239
# [58]	validation_0-rmse:66.90291
# [59]	validation_0-rmse:66.54006
# [60]	validation_0-rmse:66.19839
# [61]	validation_0-rmse:65.84979
# [62]	validation_0-rmse:65.49082
# [63]	validation_0-rmse:65.12670
# [64]	validation_0-rmse:64.77437
# [65]	validation_0-rmse:64.43245
# [66]	validation_0-rmse:64.06956
# [67]	validation_0-rmse:63.72434
# [68]	validation_0-rmse:63.38176
# [69]	validation_0-rmse:63.02659
# [70]	validation_0-rmse:62.68061
# [71]	validation_0-rmse:62.34702
# [72]	validation_0-rmse:62.02221
# [73]	validation_0-rmse:61.69447
# [74]	validation_0-rmse:61.33215
# [75]	validation_0-rmse:60.99647
# [76]	validation_0-rmse:60.65882
# [77]	validation_0-rmse:60.33443
# [78]	validation_0-rmse:60.01794
# [79]	validation_0-rmse:59.70575
# [80]	validation_0-rmse:59.36337
# [81]	validation_0-rmse:59.06298
# [82]	validation_0-rmse:58.75440
# [83]	validation_0-rmse:58.44004
# [84]	validation_0-rmse:58.11599
# [85]	validation_0-rmse:57.80155
# [86]	validation_0-rmse:57.49712
# [87]	validation_0-rmse:57.19190
# [88]	validation_0-rmse:56.89271
# [89]	validation_0-rmse:56.59094
# [90]	validation_0-rmse:56.29572
# [91]	validation_0-rmse:56.01313
# [92]	validation_0-rmse:55.71855
# [93]	validation_0-rmse:55.42040
# [94]	validation_0-rmse:55.12740
# [95]	validation_0-rmse:54.83195
# [96]	validation_0-rmse:54.55681
# [97]	validation_0-rmse:54.28128
# [98]	validation_0-rmse:53.98645
# [99]	validation_0-rmse:53.69624
# [100]	validation_0-rmse:53.41892
# [101]	validation_0-rmse:53.13402
# [102]	validation_0-rmse:52.85496
# [103]	validation_0-rmse:52.58713
# [104]	validation_0-rmse:52.31185
# [105]	validation_0-rmse:52.04788
# [106]	validation_0-rmse:51.77864
# [107]	validation_0-rmse:51.52768
# [108]	validation_0-rmse:51.28387
# [109]	validation_0-rmse:51.03782
# [110]	validation_0-rmse:50.78886
# [111]	validation_0-rmse:50.53623
# [112]	validation_0-rmse:50.27398
# [113]	validation_0-rmse:50.02162
# [114]	validation_0-rmse:49.77768
# [115]	validation_0-rmse:49.53423
# [116]	validation_0-rmse:49.30167
# [117]	validation_0-rmse:49.05912
# [118]	validation_0-rmse:48.80975
# [119]	validation_0-rmse:48.58369
# [120]	validation_0-rmse:48.33924
# [121]	validation_0-rmse:48.10654
# [122]	validation_0-rmse:47.86752
# [123]	validation_0-rmse:47.64821
# [124]	validation_0-rmse:47.42320
# [125]	validation_0-rmse:47.19365
# [126]	validation_0-rmse:46.95961
# [127]	validation_0-rmse:46.74603
# [128]	validation_0-rmse:46.52571
# [129]	validation_0-rmse:46.29854
# [130]	validation_0-rmse:46.08466
# [131]	validation_0-rmse:45.85280
# [132]	validation_0-rmse:45.63370
# [133]	validation_0-rmse:45.41981
# [134]	validation_0-rmse:45.20162
# [135]	validation_0-rmse:44.98923
# [136]	validation_0-rmse:44.77348
# [137]	validation_0-rmse:44.55593
# [138]	validation_0-rmse:44.35236
# [139]	validation_0-rmse:44.14624
# [140]	validation_0-rmse:43.92824
# [141]	validation_0-rmse:43.71006
# [142]	validation_0-rmse:43.51836
# [143]	validation_0-rmse:43.32345
# [144]	validation_0-rmse:43.11703
# [145]	validation_0-rmse:42.90391
# [146]	validation_0-rmse:42.70670
# [147]	validation_0-rmse:42.50564
# [148]	validation_0-rmse:42.31626
# [149]	validation_0-rmse:42.10111
# [150]	validation_0-rmse:41.90803
# [151]	validation_0-rmse:41.71482
# [152]	validation_0-rmse:41.52501
# [153]	validation_0-rmse:41.33238
# [154]	validation_0-rmse:41.15346
# [155]	validation_0-rmse:40.96430
# [156]	validation_0-rmse:40.78750
# [157]	validation_0-rmse:40.59723
# [158]	validation_0-rmse:40.41024
# [159]	validation_0-rmse:40.22321
# [160]	validation_0-rmse:40.03405
# [161]	validation_0-rmse:39.84541
# [162]	validation_0-rmse:39.65743
# [163]	validation_0-rmse:39.48197
# [164]	validation_0-rmse:39.31715
# [165]	validation_0-rmse:39.15177
# [166]	validation_0-rmse:38.99577
# [167]	validation_0-rmse:38.82432
# [168]	validation_0-rmse:38.65210
# [169]	validation_0-rmse:38.47431
# [170]	validation_0-rmse:38.30060
# [171]	validation_0-rmse:38.14944
# [172]	validation_0-rmse:37.98743
# [173]	validation_0-rmse:37.82145
# [174]	validation_0-rmse:37.66168
# [175]	validation_0-rmse:37.50364
# [176]	validation_0-rmse:37.33190
# [177]	validation_0-rmse:37.17998
# [178]	validation_0-rmse:37.01355
# [179]	validation_0-rmse:36.85957
# [180]	validation_0-rmse:36.69502
# [181]	validation_0-rmse:36.54652
# [182]	validation_0-rmse:36.40161
# [183]	validation_0-rmse:36.25446
# [184]	validation_0-rmse:36.10590
# [185]	validation_0-rmse:35.96584
# [186]	validation_0-rmse:35.81966
# [187]	validation_0-rmse:35.66700
# [188]	validation_0-rmse:35.50848
# [189]	validation_0-rmse:35.35954
# [190]	validation_0-rmse:35.20458
# [191]	validation_0-rmse:35.06754
# [192]	validation_0-rmse:34.93461
# [193]	validation_0-rmse:34.80126
# [194]	validation_0-rmse:34.66403
# [195]	validation_0-rmse:34.52683
# [196]	validation_0-rmse:34.40005
# [197]	validation_0-rmse:34.26030
# [198]	validation_0-rmse:34.12376
# [199]	validation_0-rmse:33.96967
# [200]	validation_0-rmse:33.84302
# [201]	validation_0-rmse:33.71495
# [202]	validation_0-rmse:33.59478
# [203]	validation_0-rmse:33.47254
# [204]	validation_0-rmse:33.35138
# [205]	validation_0-rmse:33.22411
# [206]	validation_0-rmse:33.09049
# [207]	validation_0-rmse:32.97114
# [208]	validation_0-rmse:32.85345
# [209]	validation_0-rmse:32.74268
# [210]	validation_0-rmse:32.62607
# [211]	validation_0-rmse:32.50821
# [212]	validation_0-rmse:32.38890
# [213]	validation_0-rmse:32.28079
# [214]	validation_0-rmse:32.16826
# [215]	validation_0-rmse:32.05759
# [216]	validation_0-rmse:31.93968
# [217]	validation_0-rmse:31.83473
# [218]	validation_0-rmse:31.72232
# [219]	validation_0-rmse:31.61751
# [220]	validation_0-rmse:31.51185
# [221]	validation_0-rmse:31.40308
# [222]	validation_0-rmse:31.29878
# [223]	validation_0-rmse:31.19479
# [224]	validation_0-rmse:31.09227
# [225]	validation_0-rmse:30.99433
# [226]	validation_0-rmse:30.89215
# [227]	validation_0-rmse:30.78660
# [228]	validation_0-rmse:30.65896
# [229]	validation_0-rmse:30.54437
# [230]	validation_0-rmse:30.43976
# [231]	validation_0-rmse:30.34605
# [232]	validation_0-rmse:30.25344
# [233]	validation_0-rmse:30.16146
# [234]	validation_0-rmse:30.06172
# [235]	validation_0-rmse:29.96463
# [236]	validation_0-rmse:29.86965
# [237]	validation_0-rmse:29.76359
# [238]	validation_0-rmse:29.67989
# [239]	validation_0-rmse:29.55845
# [240]	validation_0-rmse:29.46474
# [241]	validation_0-rmse:29.37391
# [242]	validation_0-rmse:29.28719
# [243]	validation_0-rmse:29.20980
# [244]	validation_0-rmse:29.13682
# [245]	validation_0-rmse:29.04725
# [246]	validation_0-rmse:28.96014
# [247]	validation_0-rmse:28.87788
# [248]	validation_0-rmse:28.78730
# [249]	validation_0-rmse:28.70616
# [250]	validation_0-rmse:28.62687
# [251]	validation_0-rmse:28.54380
# [252]	validation_0-rmse:28.46493
# [253]	validation_0-rmse:28.38372
# [254]	validation_0-rmse:28.30493
# [255]	validation_0-rmse:28.23607
# [256]	validation_0-rmse:28.16071
# [257]	validation_0-rmse:28.08025
# [258]	validation_0-rmse:28.01266
# [259]	validation_0-rmse:27.92679
# [260]	validation_0-rmse:27.85439
# [261]	validation_0-rmse:27.77058
# [262]	validation_0-rmse:27.70522
# [263]	validation_0-rmse:27.63471
# [264]	validation_0-rmse:27.54327
# [265]	validation_0-rmse:27.46750
# [266]	validation_0-rmse:27.40139
# [267]	validation_0-rmse:27.32616
# [268]	validation_0-rmse:27.26341
# [269]	validation_0-rmse:27.16936
# [270]	validation_0-rmse:27.10614
# [271]	validation_0-rmse:27.03283
# [272]	validation_0-rmse:26.96995
# [273]	validation_0-rmse:26.91004
# [274]	validation_0-rmse:26.84506
# [275]	validation_0-rmse:26.78241
# [276]	validation_0-rmse:26.71604
# [277]	validation_0-rmse:26.65413
# [278]	validation_0-rmse:26.59382
# [279]	validation_0-rmse:26.52860
# [280]	validation_0-rmse:26.46163
# [281]	validation_0-rmse:26.39773
# [282]	validation_0-rmse:26.33710
# [283]	validation_0-rmse:26.27060
# [284]	validation_0-rmse:26.20593
# [285]	validation_0-rmse:26.14638
# [286]	validation_0-rmse:26.09253
# [287]	validation_0-rmse:26.02682
# [288]	validation_0-rmse:25.96526
# [289]	validation_0-rmse:25.91071
# [290]	validation_0-rmse:25.84670
# [291]	validation_0-rmse:25.79964
# [292]	validation_0-rmse:25.74295
# [293]	validation_0-rmse:25.68331
# [294]	validation_0-rmse:25.62315
# [295]	validation_0-rmse:25.56738
# [296]	validation_0-rmse:25.51017
# [297]	validation_0-rmse:25.44997
# [298]	validation_0-rmse:25.40384
# [299]	validation_0-rmse:25.34881
# [300]	validation_0-rmse:25.28516
# [301]	validation_0-rmse:25.22888
# [302]	validation_0-rmse:25.17137
# [303]	validation_0-rmse:25.12185
# [304]	validation_0-rmse:25.08587
# [305]	validation_0-rmse:25.03432
# ...
# [102]	validation_0-rmse:66.31172
# [103]	validation_0-rmse:65.91255
# [104]	validation_0-rmse:65.51538
# [105]	validation_0-rmse:65.11349
# [106]	validation_0-rmse:64.73150
# [107]	validation_0-rmse:64.33970
# [108]	validation_0-rmse:63.92135
# [109]	validation_0-rmse:63.54296
# [110]	validation_0-rmse:63.15285
# [111]	validation_0-rmse:62.75999
# [112]	validation_0-rmse:62.36860
# [113]	validation_0-rmse:61.99901
# [114]	validation_0-rmse:61.62493
# [115]	validation_0-rmse:61.24251
# [116]	validation_0-rmse:60.84991
# [117]	validation_0-rmse:60.48456
# [118]	validation_0-rmse:60.12481
# [119]	validation_0-rmse:59.76080
# [120]	validation_0-rmse:59.39669
# [121]	validation_0-rmse:59.02804
# [122]	validation_0-rmse:58.68849
# [123]	validation_0-rmse:58.32955
# [124]	validation_0-rmse:57.98200
# [125]	validation_0-rmse:57.64053
# [126]	validation_0-rmse:57.28113
# [127]	validation_0-rmse:56.95073
# [128]	validation_0-rmse:56.62380
# [129]	validation_0-rmse:56.29110
# [130]	validation_0-rmse:55.97135
# [131]	validation_0-rmse:55.62617
# [132]	validation_0-rmse:55.29372
# [133]	validation_0-rmse:54.97753
# [134]	validation_0-rmse:54.62942
# [135]	validation_0-rmse:54.29546
# [136]	validation_0-rmse:53.96579
# [137]	validation_0-rmse:53.64222
# [138]	validation_0-rmse:53.32874
# [139]	validation_0-rmse:52.99403
# [140]	validation_0-rmse:52.68095
# [141]	validation_0-rmse:52.37558
# [142]	validation_0-rmse:52.07017
# [143]	validation_0-rmse:51.77050
# [144]	validation_0-rmse:51.44508
# [145]	validation_0-rmse:51.11211
# [146]	validation_0-rmse:50.81181
# [147]	validation_0-rmse:50.50600
# [148]	validation_0-rmse:50.20219
# [149]	validation_0-rmse:49.89399
# [150]	validation_0-rmse:49.58791
# [151]	validation_0-rmse:49.29428
# [152]	validation_0-rmse:48.99403
# [153]	validation_0-rmse:48.69440
# [154]	validation_0-rmse:48.40456
# [155]	validation_0-rmse:48.11683
# [156]	validation_0-rmse:47.83703
# [157]	validation_0-rmse:47.55385
# [158]	validation_0-rmse:47.25565
# [159]	validation_0-rmse:46.98719
# [160]	validation_0-rmse:46.69879
# [161]	validation_0-rmse:46.43087
# [162]	validation_0-rmse:46.14237
# [163]	validation_0-rmse:45.86733
# [164]	validation_0-rmse:45.60773
# [165]	validation_0-rmse:45.34819
# [166]	validation_0-rmse:45.07542
# [167]	validation_0-rmse:44.80611
# [168]	validation_0-rmse:44.53635
# [169]	validation_0-rmse:44.26601
# [170]	validation_0-rmse:44.00229
# [171]	validation_0-rmse:43.74384
# [172]	validation_0-rmse:43.50389
# [173]	validation_0-rmse:43.25122
# [174]	validation_0-rmse:42.99101
# [175]	validation_0-rmse:42.73002
# [176]	validation_0-rmse:42.47733
# [177]	validation_0-rmse:42.22926
# [178]	validation_0-rmse:41.98013
# [179]	validation_0-rmse:41.74279
# [180]	validation_0-rmse:41.47878
# [181]	validation_0-rmse:41.21605
# [182]	validation_0-rmse:40.97967
# [183]	validation_0-rmse:40.72552
# [184]	validation_0-rmse:40.50193
# [185]	validation_0-rmse:40.28005
# [186]	validation_0-rmse:40.04925
# [187]	validation_0-rmse:39.81527
# [188]	validation_0-rmse:39.59119
# [189]	validation_0-rmse:39.35223
# [190]	validation_0-rmse:39.12511
# [191]	validation_0-rmse:38.88861
# [192]	validation_0-rmse:38.67961
# [193]	validation_0-rmse:38.47300
# [194]	validation_0-rmse:38.26528
# [195]	validation_0-rmse:38.04916
# [196]	validation_0-rmse:37.81102
# [197]	validation_0-rmse:37.61236
# [198]	validation_0-rmse:37.40077
# [199]	validation_0-rmse:37.18802
# [200]	validation_0-rmse:36.97449
# [201]	validation_0-rmse:36.74878
# [202]	validation_0-rmse:36.55151
# [203]	validation_0-rmse:36.36227
# [204]	validation_0-rmse:36.15629
# [205]	validation_0-rmse:35.96077
# [206]	validation_0-rmse:35.76719
# [207]	validation_0-rmse:35.56006
# [208]	validation_0-rmse:35.32583
# [209]	validation_0-rmse:35.13605
# [210]	validation_0-rmse:34.93861
# [211]	validation_0-rmse:34.74203
# [212]	validation_0-rmse:34.56430
# [213]	validation_0-rmse:34.37002
# [214]	validation_0-rmse:34.16634
# [215]	validation_0-rmse:33.96733
# [216]	validation_0-rmse:33.76881
# [217]	validation_0-rmse:33.57912
# [218]	validation_0-rmse:33.39141
# [219]	validation_0-rmse:33.21296
# [220]	validation_0-rmse:33.01358
# [221]	validation_0-rmse:32.84691
# [222]	validation_0-rmse:32.65687
# [223]	validation_0-rmse:32.47439
# [224]	validation_0-rmse:32.27697
# [225]	validation_0-rmse:32.10551
# [226]	validation_0-rmse:31.93832
# [227]	validation_0-rmse:31.75469
# [228]	validation_0-rmse:31.58946
# [229]	validation_0-rmse:31.39797
# [230]	validation_0-rmse:31.21421
# [231]	validation_0-rmse:31.04368
# [232]	validation_0-rmse:30.87087
# [233]	validation_0-rmse:30.71795
# [234]	validation_0-rmse:30.55411
# [235]	validation_0-rmse:30.38037
# [236]	validation_0-rmse:30.21532
# [237]	validation_0-rmse:30.06257
# [238]	validation_0-rmse:29.89734
# [239]	validation_0-rmse:29.73913
# [240]	validation_0-rmse:29.58055
# [241]	validation_0-rmse:29.43527
# [242]	validation_0-rmse:29.28057
# [243]	validation_0-rmse:29.12030
# [244]	validation_0-rmse:28.97169
# [245]	validation_0-rmse:28.81943
# [246]	validation_0-rmse:28.66481
# [247]	validation_0-rmse:28.52882
# [248]	validation_0-rmse:28.39205
# [249]	validation_0-rmse:28.23506
# [250]	validation_0-rmse:28.07847
# [251]	validation_0-rmse:27.93899
# [252]	validation_0-rmse:27.79953
# [253]	validation_0-rmse:27.65467
# [254]	validation_0-rmse:27.50931
# [255]	validation_0-rmse:27.37688
# [256]	validation_0-rmse:27.24605
# [257]	validation_0-rmse:27.10360
# [258]	validation_0-rmse:26.96444
# [259]	validation_0-rmse:26.83352
# [260]	validation_0-rmse:26.69115
# [261]	validation_0-rmse:26.55149
# [262]	validation_0-rmse:26.41854
# [263]	validation_0-rmse:26.30271
# [264]	validation_0-rmse:26.17053
# [265]	validation_0-rmse:26.05621
# [266]	validation_0-rmse:25.93701
# [267]	validation_0-rmse:25.81344
# [268]	validation_0-rmse:25.68698
# [269]	validation_0-rmse:25.56389
# [270]	validation_0-rmse:25.43903
# [271]	validation_0-rmse:25.32742
# [272]	validation_0-rmse:25.19495
# [273]	validation_0-rmse:25.07559
# [274]	validation_0-rmse:24.95537
# [275]	validation_0-rmse:24.84538
# [276]	validation_0-rmse:24.73770
# [277]	validation_0-rmse:24.62409
# [278]	validation_0-rmse:24.50968
# [279]	validation_0-rmse:24.38287
# [280]	validation_0-rmse:24.26733
# [281]	validation_0-rmse:24.15556
# [282]	validation_0-rmse:24.04413
# [283]	validation_0-rmse:23.92985
# [284]	validation_0-rmse:23.81970
# [285]	validation_0-rmse:23.71108
# [286]	validation_0-rmse:23.59382
# [287]	validation_0-rmse:23.48703
# [288]	validation_0-rmse:23.39108
# [289]	validation_0-rmse:23.29974
# [290]	validation_0-rmse:23.19920
# [291]	validation_0-rmse:23.10810
# [292]	validation_0-rmse:23.00449
# [293]	validation_0-rmse:22.90591
# [294]	validation_0-rmse:22.81411
# [295]	validation_0-rmse:22.71186
# [296]	validation_0-rmse:22.60837
# [297]	validation_0-rmse:22.51399
# [298]	validation_0-rmse:22.41424
# [299]	validation_0-rmse:22.32101
# [300]	validation_0-rmse:22.23011
# [301]	validation_0-rmse:22.13522
# [302]	validation_0-rmse:22.03676
# [303]	validation_0-rmse:21.93628
# [304]	validation_0-rmse:21.85317
# [305]	validation_0-rmse:21.77421
# [306]	validation_0-rmse:21.69301
# [307]	validation_0-rmse:21.61657
# [308]	validation_0-rmse:21.52399
# [309]	validation_0-rmse:21.44035
# [310]	validation_0-rmse:21.36130
# [311]	validation_0-rmse:21.26708
# [312]	validation_0-rmse:21.19593
# [313]	validation_0-rmse:21.10878
# [314]	validation_0-rmse:21.02497
# [315]	validation_0-rmse:20.95253
# [316]	validation_0-rmse:20.88271
# [317]	validation_0-rmse:20.80146
# [318]	validation_0-rmse:20.71707
# [319]	validation_0-rmse:20.63853
# [320]	validation_0-rmse:20.55465
# [321]	validation_0-rmse:20.48369
# [322]	validation_0-rmse:20.40209
# [323]	validation_0-rmse:20.32778
# [324]	validation_0-rmse:20.24674
# [325]	validation_0-rmse:20.15908
# [326]	validation_0-rmse:20.08833
# [327]	validation_0-rmse:20.01514
# [328]	validation_0-rmse:19.94497
# [329]	validation_0-rmse:19.88562
# [330]	validation_0-rmse:19.80801
# [331]	validation_0-rmse:19.75105
# [332]	validation_0-rmse:19.68927
# [333]	validation_0-rmse:19.63619
# [334]	validation_0-rmse:19.56097
# [335]	validation_0-rmse:19.50656
# [336]	validation_0-rmse:19.44578
# [337]	validation_0-rmse:19.37869
# [338]	validation_0-rmse:19.31594
# [339]	validation_0-rmse:19.24963
# [340]	validation_0-rmse:19.20068
# [341]	validation_0-rmse:19.13818
# [342]	validation_0-rmse:19.07771
# [343]	validation_0-rmse:19.01213
# [344]	validation_0-rmse:18.95430
# [345]	validation_0-rmse:18.90334
# [346]	validation_0-rmse:18.84103
# [347]	validation_0-rmse:18.78246
# [348]	validation_0-rmse:18.71316
# [349]	validation_0-rmse:18.65515
# [350]	validation_0-rmse:18.60538
# [351]	validation_0-rmse:18.55679
# [352]	validation_0-rmse:18.49398
# [353]	validation_0-rmse:18.42782
# [354]	validation_0-rmse:18.36598
# [355]	validation_0-rmse:18.31567
# [356]	validation_0-rmse:18.26014
# [357]	validation_0-rmse:18.20001
# [358]	validation_0-rmse:18.15391
# [359]	validation_0-rmse:18.10888
# [360]	validation_0-rmse:18.06138
# [361]	validation_0-rmse:18.00981
# [362]	validation_0-rmse:17.96936
# [363]	validation_0-rmse:17.92835
# [364]	validation_0-rmse:17.89046
# [365]	validation_0-rmse:17.84461
# [366]	validation_0-rmse:17.79314
# [367]	validation_0-rmse:17.75100
# [368]	validation_0-rmse:17.70261
# [369]	validation_0-rmse:17.66530
# [370]	validation_0-rmse:17.62691
# [371]	validation_0-rmse:17.58758
# [372]	validation_0-rmse:17.55249
# [373]	validation_0-rmse:17.51768
# [374]	validation_0-rmse:17.47733
# [375]	validation_0-rmse:17.44139
# [376]	validation_0-rmse:17.40544
# [377]	validation_0-rmse:17.36676
# [378]	validation_0-rmse:17.33591
# [379]	validation_0-rmse:17.30335
# [380]	validation_0-rmse:17.26556
# [381]	validation_0-rmse:17.23270
# [382]	validation_0-rmse:17.19501
# [383]	validation_0-rmse:17.15996
# [384]	validation_0-rmse:17.12229
# [385]	validation_0-rmse:17.08225
# [386]	validation_0-rmse:17.04595
# [387]	validation_0-rmse:17.01146
# [388]	validation_0-rmse:16.98067
# [389]	validation_0-rmse:16.95306
# [390]	validation_0-rmse:16.92747
# [391]	validation_0-rmse:16.89008
# [392]	validation_0-rmse:16.85639
# [393]	validation_0-rmse:16.82089
# [394]	validation_0-rmse:16.78965
# [395]	validation_0-rmse:16.76984
# [396]	validation_0-rmse:16.74166
# [397]	validation_0-rmse:16.72042
# [398]	validation_0-rmse:16.69546
# [399]	validation_0-rmse:16.66111
# [400]	validation_0-rmse:16.63192
# [401]	validation_0-rmse:16.60317
# [402]	validation_0-rmse:16.57365
# [403]	validation_0-rmse:16.55107
# [404]	validation_0-rmse:16.52272
# [405]	validation_0-rmse:16.50225
# [406]	validation_0-rmse:16.47919
# [407]	validation_0-rmse:16.45487
# [408]	validation_0-rmse:16.43568
# [409]	validation_0-rmse:16.41224
# [410]	validation_0-rmse:16.39657
# [411]	validation_0-rmse:16.37010
# [412]	validation_0-rmse:16.35317
# [413]	validation_0-rmse:16.33095
# [414]	validation_0-rmse:16.31576
# [415]	validation_0-rmse:16.29819
# [416]	validation_0-rmse:16.27507
# [417]	validation_0-rmse:16.24933
# [418]	validation_0-rmse:16.22503
# [419]	validation_0-rmse:16.20290
# [420]	validation_0-rmse:16.18288
# [421]	validation_0-rmse:16.16097
# [422]	validation_0-rmse:16.14485
# [423]	validation_0-rmse:16.12332
# [424]	validation_0-rmse:16.10736
# [425]	validation_0-rmse:16.09083
# [426]	validation_0-rmse:16.07436
# [427]	validation_0-rmse:16.06383
# [428]	validation_0-rmse:16.04834
# [429]	validation_0-rmse:16.03504
# [430]	validation_0-rmse:16.01853
# [431]	validation_0-rmse:16.00578
# [432]	validation_0-rmse:15.99445
# [433]	validation_0-rmse:15.98696
# [434]	validation_0-rmse:15.97216
# [435]	validation_0-rmse:15.95760
# [436]	validation_0-rmse:15.94670
# [437]	validation_0-rmse:15.93411
# [438]	validation_0-rmse:15.92921
# [439]	validation_0-rmse:15.92041
# [440]	validation_0-rmse:15.90926
# [441]	validation_0-rmse:15.89463
# [442]	validation_0-rmse:15.88335
# [443]	validation_0-rmse:15.87323
# [444]	validation_0-rmse:15.86262
# [445]	validation_0-rmse:15.85245
# [446]	validation_0-rmse:15.84301
# [447]	validation_0-rmse:15.83957
# [448]	validation_0-rmse:15.83101
# [449]	validation_0-rmse:15.81831
# [450]	validation_0-rmse:15.80844
# [451]	validation_0-rmse:15.80420
# [452]	validation_0-rmse:15.79492
# [453]	validation_0-rmse:15.78908
# [454]	validation_0-rmse:15.77696
# [455]	validation_0-rmse:15.77093
# [456]	validation_0-rmse:15.76525
# [457]	validation_0-rmse:15.75227
# [458]	validation_0-rmse:15.74615
# [459]	validation_0-rmse:15.74169
# [460]	validation_0-rmse:15.73476
# [461]	validation_0-rmse:15.72740
# [462]	validation_0-rmse:15.72061
# [463]	validation_0-rmse:15.71473
# [464]	validation_0-rmse:15.70994
# [465]	validation_0-rmse:15.70772
# [466]	validation_0-rmse:15.70049
# [467]	validation_0-rmse:15.69345
# [468]	validation_0-rmse:15.69403
# [469]	validation_0-rmse:15.69181
# [470]	validation_0-rmse:15.69362
# [471]	validation_0-rmse:15.68567
# [472]	validation_0-rmse:15.67574
# [473]	validation_0-rmse:15.67248
# [474]	validation_0-rmse:15.66874
# [475]	validation_0-rmse:15.67063
# [476]	validation_0-rmse:15.66766
# [477]	validation_0-rmse:15.66513
# [478]	validation_0-rmse:15.66113
# [479]	validation_0-rmse:15.65959
# [480]	validation_0-rmse:15.66993
# [481]	validation_0-rmse:15.66078
# [482]	validation_0-rmse:15.66117
# [483]	validation_0-rmse:15.66466
# [484]	validation_0-rmse:15.65671
# [485]	validation_0-rmse:15.66230
# [486]	validation_0-rmse:15.65716
# [487]	validation_0-rmse:15.65753
# [488]	validation_0-rmse:15.65770
# [489]	validation_0-rmse:15.65968
# [490]	validation_0-rmse:15.65520
# [491]	validation_0-rmse:15.65277
# [492]	validation_0-rmse:15.65605
# [493]	validation_0-rmse:15.65573
# [494]	validation_0-rmse:15.65379
# [495]	validation_0-rmse:15.65373
# [496]	validation_0-rmse:15.64892
# [497]	validation_0-rmse:15.64571
# [498]	validation_0-rmse:15.64315
# [499]	validation_0-rmse:15.64210
# [500]	validation_0-rmse:15.64410
# [501]	validation_0-rmse:15.64312
# [502]	validation_0-rmse:15.64305
# [503]	validation_0-rmse:15.64471
# [504]	validation_0-rmse:15.64472
# [505]	validation_0-rmse:15.64802
# [506]	validation_0-rmse:15.64793
# [507]	validation_0-rmse:15.64548
# [508]	validation_0-rmse:15.65571
# [509]	validation_0-rmse:15.65229
# [510]	validation_0-rmse:15.65156
# [511]	validation_0-rmse:15.65471
# [512]	validation_0-rmse:15.65712
# [513]	validation_0-rmse:15.65388
# [514]	validation_0-rmse:15.65496
# [515]	validation_0-rmse:15.65546
# [516]	validation_0-rmse:15.65749
# [517]	validation_0-rmse:15.65910
# [518]	validation_0-rmse:15.65983
# [519]	validation_0-rmse:15.66072
# [520]	validation_0-rmse:15.66728
# [521]	validation_0-rmse:15.66722
# [522]	validation_0-rmse:15.67321
# [523]	validation_0-rmse:15.67111
# [524]	validation_0-rmse:15.67242
# [525]	validation_0-rmse:15.67789
# [526]	validation_0-rmse:15.68262
# [527]	validation_0-rmse:15.68295
# [528]	validation_0-rmse:15.68294
# [529]	validation_0-rmse:15.68523
# [530]	validation_0-rmse:15.68611
# [531]	validation_0-rmse:15.69064
# [532]	validation_0-rmse:15.69089
# [533]	validation_0-rmse:15.68978
# [534]	validation_0-rmse:15.69411
# [535]	validation_0-rmse:15.69881
# [536]	validation_0-rmse:15.70028
# [537]	validation_0-rmse:15.70683
# [538]	validation_0-rmse:15.71629
# [539]	validation_0-rmse:15.72274
# [540]	validation_0-rmse:15.72250
# [541]	validation_0-rmse:15.72359
# [542]	validation_0-rmse:15.72863
# [543]	validation_0-rmse:15.73477
# [544]	validation_0-rmse:15.74086
# [545]	validation_0-rmse:15.74646
# [546]	validation_0-rmse:15.75002
# [547]	validation_0-rmse:15.75763
# [548]	validation_0-rmse:15.76885
# [549]	validation_0-rmse:15.77171
# [550]	validation_0-rmse:15.77769
# [551]	validation_0-rmse:15.78366
# [552]	validation_0-rmse:15.79110
# [553]	validation_0-rmse:15.79443
# [554]	validation_0-rmse:15.79818
# [555]	validation_0-rmse:15.80319
# [556]	validation_0-rmse:15.80728
# [557]	validation_0-rmse:15.80803
# [558]	validation_0-rmse:15.81076
# [559]	validation_0-rmse:15.81636
# [560]	validation_0-rmse:15.82017
# [561]	validation_0-rmse:15.82482
# [562]	validation_0-rmse:15.83135
# [563]	validation_0-rmse:15.83843
# [564]	validation_0-rmse:15.84186
# [565]	validation_0-rmse:15.84339
# [566]	validation_0-rmse:15.84938
# [567]	validation_0-rmse:15.85107
# [568]	validation_0-rmse:15.85647
# [569]	validation_0-rmse:15.85891
# [570]	validation_0-rmse:15.86276
# [571]	validation_0-rmse:15.87375
# [572]	validation_0-rmse:15.87742
# [573]	validation_0-rmse:15.88099
# [574]	validation_0-rmse:15.88706
# [575]	validation_0-rmse:15.89366
# [576]	validation_0-rmse:15.90083
# [577]	validation_0-rmse:15.90598
# [578]	validation_0-rmse:15.91054
# [579]	validation_0-rmse:15.91791
# Linear Regression RMSE: 8.014797634175682
# XGBoost RMSE: 14.316805704016321
# --------------------------------------------------------
# Linear Regression: 35.50272421391273, XGBoost: 33.17713611253945

# %% [markdown]
# ## 5. Results
# We trained and evaluated three models: Linear Regression, XGBoost, and Prophet, comparing them based on MAE, MSE, RMSE and MAPE.
#
# XGBoost performed the worst among the three models, showing the highest RMSE and MAE. While XGBoost is a complex machine learning algorithm for tabular data, it is not inherently designed for time-series forecasting. Unlike models specifically tailored to capture temporal dependencies, XGBoost requires extensive feature engineering, such as lag variables and rolling statistics, to approximate time-dependent patterns. Despite tuning hyperparameters to improve performance, the model struggled to generalize well over unseen time periods. However, the computational time for XGBoost was relatively short, taking only a few seconds, which made it a viable option for testing. Its training time was not a significant constraint, but its inability to effectively capture long-term trends and seasonal cycles made it less suitable for this task.
#
# Prophet, on the other hand, outperformed the other models by achieving the lowest RMSE and MAE. Unlike XGBoost, Prophet is specifically designed for time-series forecasting and naturally incorporates seasonality, trend changes, and external regressors without requiring extensive feature engineering. The ability to model holidays and other special events allowed Prophet to adapt to irregular fluctuations in energy prices that were influenced by external factors such as national holidays or changes in market demand. The model’s use of multiplicative seasonality further improved accuracy, as energy prices exhibit percentage-based fluctuations rather than purely additive changes. However, a key consideration is that Prophet had by far the highest computational time, often taking multiple minutes to train, compared to the seconds it took for Linear Regression and XGBoost. While Prophet's accuracy was superior, its long training time makes it less practical in environments requiring frequent testing or fast iteration.
#
# Linear Regression performed better than expected, with results that were relatively close to those of Prophet. One key reason for its strong performance was the presence of moving averages, which helped smooth short-term fluctuations in the energy prices. By incorporating moving averages, the model was able to capture a form of seasonality indirectly, as the smoothed data preserved some of the cyclical patterns present in energy prices. This approach allowed Linear Regression to approximate longer-term trends while reducing noise from sudden price spikes or irregular fluctuations.
#
# However, despite the benefits of moving averages, Linear Regression still struggled to fully capture more complex seasonal effects and abrupt trend changes. Unlike Prophet, which explicitly models multiple seasonal components and adjusts for holiday effects, Linear Regression could only approximate these patterns through indirect smoothing techniques. As a result, while the model performed better than XGBoost, it was still outperformed by Prophet, which could natively account for seasonality, trend shifts, and external regressors.
# Overall, Prophet emerged as the best model due to its ability to handle seasonal effects, holidays, and external variables naturally. Linear Regression performed better than expected because of the strong linear structure in energy prices, whereas XGBoost struggled due to its lack of native time-series modeling capabilities and its sensitivity to short-term fluctuations.

# %% [markdown]
# ## Final Prediction 18.02.2025 00:00:00 - 19.02.2025 00:00:00

# %%
from src.final_prediction import fill_up_e_prices, fill_up_energy_mix, fetch_forecast_and_update_csv
# fill_up_e_prices()
# fill_up_energy_mix()
# fetch_forecast_and_update_csv()


# Columns to use from the datasets
COLUMNS = [
    "Price", "Hydro", "Pumped storage generation", "Solar", 
    "Wind offshore", "Wind onshore", "temperature_2m", "precipitation", 
    "wind_speed_100m", "direct_radiation"
]

# Final features used for model training and forecasting
FINAL_FEATURES = [
    "hour", "dayofyear", "dayofweek",
    "Hydro", "Pumped storage generation",
    "Solar", "Wind offshore", "Wind onshore",
    "temperature_2m", "precipitation", "wind_speed_100m", "direct_radiation"
]
# =============================================================================
# Data Preparation
# =============================================================================


start_date = '2025-02-11 00:00:00'
end_date = '2025-02-11 23:00:00'
    
# ------------------------- Prophet Model -------------------------
# Initialize the Prophet model with custom features.
prophet_model = init_prophet_model(FINAL_FEATURES)

# Extend the training data with any benchmarking data available before the current window.
feature_df = create_features(merged_df[COLUMNS])

# Split the data into training and benchmarking sets
training_set = feature_df.loc[:start_date]
prediction_set = feature_df.loc[start_date:end_date]

# Prepare the training data for Prophet.
# - The forecast dataframe requires a datetime column named "ds" and our target columns to be named "y".
prophet_training_data = (
    training_set[["Price"] + FINAL_FEATURES]
    .rename(columns={"Price": "y"})
    .reset_index()
    .rename(columns={"index": "ds"})
    .dropna()
)

# Prepare data for Prophet forecasting: 
# - The forecast dataframe requires a datetime column named "ds".
prophet_forecast_data = (
    prediction_set[FINAL_FEATURES]
    .reset_index()
    .rename(columns={"index": "ds"})
)

# Fit the Prophet model and make predictions.
prophet_model.fit(prophet_training_data)
prophet_forecast = prophet_model.predict(prophet_forecast_data)["yhat"]


prophet_forecast.to_csv("forecast.csv", index=True)
